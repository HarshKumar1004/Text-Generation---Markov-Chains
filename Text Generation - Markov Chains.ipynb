# %% [markdown]
# # Text Generation - Markov Chains
#
# ## Introduction
# Markov Chains are a mathematical way of representing <b>how systems change over time. </b>
# Markov chains can be used for basic text generation. Think about every word in a corpus as a state. We can make a simple assumption that the next word is only dependent on the previous word - which is the basic assumption of a Markov chain.
#
# To create a Markov Chain , we create a dictionary for a corpus where <b> the keys are the current state </b> and <b>the values are the options for the nest state.</b> We then write a function to randomly generate next terms.
#
# Markov chains don't generate text as well as deep learning (LSTMs), but it's a good (and fun!) start.

# %% [markdown]
# ## Select Text to Imitate
#
# In this notebook, we're specifically going to <b> generate text from Inspirational and Motivational Quotes </b>

# %%
import pandas as pd #for working with dataframes

# %%
#Reading the dataset file
data_df= pd.read_excel(r'C:\Users\Asus\Desktop\DS+ML+NLP\Projects(Github)\Text Generation -Markov Chains\quotes_dataset.xlsx')

# %%
data_df
# Out:
#     The best preparation for tomorrow is doing your best today.  Unnamed: 1
# 0    Put your heart, mind, and soul into even your ...                  NaN
# 1    I can't change the direction of the wind, but ...                  NaN
# 2    We must let go of the life we have planned, so...                  NaN
# 3    Start by doing what's necessary; then do what'...                  NaN
# 4    Happiness is not something you postpone for th...                  NaN
# ..                                                 ...                  ...
# 396  I want to be an inspirational model. I want pe...                  NaN
# 397  I will always desire to play with Bruce Spring...                  NaN
# 398  There have been many different artists that ha...                  NaN
# 399  Lee's great gifts are teaching and inspiration...                  NaN
# 400  I wanted to do something inspirational for my ...                  NaN
#
# [401 rows x 2 columns]

# %%
#naming the columns
data_df.columns= ['Quotes','a']

# %%
data_df
# Out:
#                                                 Quotes   a
# 0    Put your heart, mind, and soul into even your ... NaN
# 1    I can't change the direction of the wind, but ... NaN
# 2    We must let go of the life we have planned, so... NaN
# 3    Start by doing what's necessary; then do what'... NaN
# 4    Happiness is not something you postpone for th... NaN
# ..                                                 ...  ..
# 396  I want to be an inspirational model. I want pe... NaN
# 397  I will always desire to play with Bruce Spring... NaN
# 398  There have been many different artists that ha... NaN
# 399  Lee's great gifts are teaching and inspiration... NaN
# 400  I wanted to do something inspirational for my ... NaN
#
# [401 rows x 2 columns]

# %%
#deleting the additional empty column
data_df.pop('a')
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 396   NaN
# 397   NaN
# 398   NaN
# 399   NaN
# 400   NaN
# Name: a, Length: 401, dtype: float64

# %%
# Let's take a look at the updated df
data_df
# Out:
#                                                 Quotes
# 0    Put your heart, mind, and soul into even your ...
# 1    I can't change the direction of the wind, but ...
# 2    We must let go of the life we have planned, so...
# 3    Start by doing what's necessary; then do what'...
# 4    Happiness is not something you postpone for th...
# ..                                                 ...
# 396  I want to be an inspirational model. I want pe...
# 397  I will always desire to play with Bruce Spring...
# 398  There have been many different artists that ha...
# 399  Lee's great gifts are teaching and inspiration...
# 400  I wanted to do something inspirational for my ...
#
# [401 rows x 1 columns]

# %%
corpus = ''
 
# iterate through the combined dataframe file
for val in data_df.Quotes:
     
    # typecaste each val to string
    val = str(val)
 
   
      # split the value
    tokens = val.split()   
    corpus += " ".join(tokens)+" "

# %%
#corpus of our data
corpus
# Out:
# "Put your heart, mind, and soul into even your smallest acts. This is the secret of success. I can't change the direction of the wind, but I can adjust my sails to always reach my destination. We must let go of the life we have planned, so as to accept the one that is waiting for us. Start by doing what's necessary; then do what's possible; and suddenly you are doing the impossible. Happiness is not something you postpone for the future; it is something you design for the present. It is during our darkest moments that we must focus to see the light. Try to be a rainbow in someone's cloud. From a small seed a mighty trunk may grow. Nothing is impossible, the word itself says 'I'm possible'! Your work is going to fill a large part of your life, and the only way to be truly satisfied is to do what you believe is great work. And the only way to do great work is to love what you do. If you haven't found it yet, keep looking. Don't settle. As with all matters of the heart, you'll know when you find it. Change your thoughts and you change your world. Health is the greatest gift, contentment the greatest wealth, faithfulness the best relationship. Today I choose life. Every morning when I wake up I can choose joy, happiness, negativity, pain... To feel the freedom that comes from being able to continue to make mistakes and choices - today I choose to feel life, not to deny my humanity but embrace it. Believe you can and you're halfway there. My mission in life is not merely to survive, but to thrive; and to do so with some passion, some compassion, some humor, and some style. No act of kindness, no matter how small, is ever wasted. Keep your face always toward the sunshine - and shadows will fall behind you. If opportunity doesn't knock, build a door. Perfection is not attainable, but if we chase perfection we can catch excellence. What lies behind you and what lies in front of you, pales in comparison to what lies inside of you. What we think, we become. Let us remember: One book, one pen, one child, and one teacher can change the world. We know what we are, but know not what we may be. Clouds come floating into my life, no longer to carry rain or usher storm, but to add color to my sunset sky. Someone is sitting in the shade today because someone planted a tree a long time ago. Let us sacrifice our today so that our children can have a better tomorrow. There are two ways of spreading light: to be the candle or the mirror that reflects it. A hero is someone who has given his or her life to something bigger than oneself. Don't judge each day by the harvest you reap but by the seeds that you plant. No matter what people tell you, words and ideas can change the world. Your present circumstances don't determine where you can go; they merely determine where you start. All you need is the plan, the road map, and the courage to press on to your destination. As we express our gratitude, we must never forget that the highest appreciation is not to utter words, but to live by them. Thousands of candles can be lighted from a single candle, and the life of the candle will not be shortened. Happiness never decreases by being shared. We can't help everyone, but everyone can help someone. I hated every minute of training, but I said, 'Don't quit. Suffer now and live the rest of your life as a champion.' When you have a dream, you've got to grab it and never let go. Turn your face to the sun and the shadows fall behind you. I will love the light for it shows me the way, yet I will endure the darkness because it shows me the stars. If you always put limit on everything you do, physical or anything else. It will spread into your work and into your life. There are no limits. There are only plateaus, and you must not stay there, you must go beyond them. You must do the things you think you cannot do. I believe in pink. I believe that laughing is the best calorie burner. I believe in kissing, kissing a lot. I believe in being strong when everything seems ...

# %% [markdown]
# ## Build a Markov Chain Function
# We are going to build a simple Markov chain function that creates a dictionary:
#
# 1. The keys should be all of the words in the corpus.
#
# 2. The values should be a list of the words that follow the keys

# %%
from collections import defaultdict
"""
A common problem that we can face when working with Python dictionaries is to try to access or modify keys that don’t exist
in the dictionary. This will raise a KeyError and break up your code execution. To handle these kinds of situations, the
standard library provides the Python defaultdict type, a dictionary-like class that’s available for you in collections.

The Python defaultdict type behaves almost exactly like a regular Python dictionary, but if you try to access or modify a 
missing key, then defaultdict will automatically create the key and generate a default value for it. This makes defaultdict
a valuable option for handling missing keys in dictionaries.
"""
def markov_chain(text):
    '''The input is a string of text and the output will be a dictionary with each word as
       a key and each value as the list of words that come after the key in the text.'''
    
    # Tokenize the text by word, though including punctuation
    words = text.split(' ')
    
    # Initialize a default dictionary to hold all of the words and next words
    m_dict = defaultdict(list)
    
    # Create a zipped list of all of the word pairs and put them in word: list of next words format
    for current_word, next_word in zip(words[0:-1], words[1:]):
        m_dict[current_word].append(next_word)

    # Convert the default dict back into a dictionary
    m_dict = dict(m_dict)
    return m_dict

# %%
# Create the dictionary
data_dict = markov_chain(corpus)
data_dict
# Out:
# {'Put': ['your'],
#  'your': ['heart,',
#   'smallest',
#   'life,',
#   'thoughts',
#   'world.',
#   'face',
#   'destination.',
#   'life',
#   'face',
#   'work',
#   'life.',
#   'life',
#   'moments',
#   'destiny',
#   'professional',
#   'creative',
#   'grasp,',
#   'bliss',
#   'mind',
#   'potential',
#   'heart.',
#   'dreams',
#   'feet',
#   'heart',
#   'spiritual',
#   'beliefs',
#   'minds',
#   'life',
#   'heart.',
#   'soul',
#   'little',
#   'own',
#   'visions',
#   'dreams',
#   'soul,',
#   'ultimate',
#   'mind',
#   'own',
#   'hands.',
#   'feet.',
#   'heart.',
#   'own',
#   'eyes',
#   'heart.',
#   'parents.',
#   'friends.',
#   'hand.',
#   'health',
#   'own',
#   'own',
#   'family',
#   'parents',
#   'everyday',
#   'dreams',
#   'whole',
#   'time,',
#   'chits,',
#   'home',
#   'entire'],
#  'heart,': ['mind,', "you'll", 'the', 'which'],
#  'mind,': ['and'],
#  'and': ['soul',
#   'suddenly',
#   'the',
#   'you',
#   'choices',
#   "you're",
#   'to',
#   'some',
#   'shadows',
#   'what',
#   'one',
#   'ideas',
#   'the',
#   'the',
#   'live',
#   'never',
#   'the',
#   'into',
#   'you',
#   'I',
#   'have',
#   'pride',
#   'never',
#   'let',
#   'by',
#   'if',
#   'your',
#   'the',
#   'our',
#   'within',
#   'I',
#   'that',
#   'the',
#   'everything',
#   'time',
#   'every',
#   'not',
#   'the',
#   'love',
#   'you',
#   'it',
#   'be',
#   'for',
#   'for',
#   'you',
#   'the',
#   'thus',
#   'memories',
#   'build',
#   'be',
#   'everything',
#   'know',
#   'selfless',
#   'I',
#   'transform',
#   'hope',
#   'glorify',
#   'that',
#   'in',
#   'it',
#   'it',
#   'receive',
#   'to',
#   'a',
#   'beauty.',
#   'your',
#   'stillness...',
#   'my',
#   'let',
#   "I've",
#   'desire',
#   'people',
#   'create.',
#   'I',
#   'it',
#   'defy',
#   'mankind',
#   'inspiration,',
#   'choose',
#   'hard',
#   'learn',
#   'wishing',
#   'good,',
#   'we',
#   'economic',
#   'my',
#   'to',
#   'honor',
#   'be',
#   'I',
#   'traditions.',
#   'not',
#   'thinks',
#   'sing',
#   'energy,',
#   'the',
#   'the',
#   'make',
#   'bent',
#   'obey',
#   'the',
#   'master',
#   'things',
#   'bling',
#   'it',
#   'great',
#   'blessings,',
#   'Preserver.',
#   'spirit',
#   'bubbles',
#   'afraid',
#   'lift',
#   'Hollywood',
#   'inspirational',
#   'rehearsal',
#   'directing',
#   'nights;',
#   'space',
#   'very',
#   'they',
#   'Northern',
#   'inspirational',
#   'should',
#   'none',
#   'inspirational',
#   'inspirational.',
#   'I',
#   'inspirational',
#   'every',
#   'enthusiastically',
#   'have',
#   'have',
#   'makes',
#   'love',
#   'affection',
#   'the',
#   'appropriate',
#   "I'm",
#   'make',
#   'worship,',
#   'about',
#   'how',
#   'smart',
#   'thought',
#   'an',
#   'get',
#   'beautiful.',
#   'I',
#   'yet',
#   'keep',
#   'confusing.',
#   'the',
#   'flaunting,',
#   'the',
#   'it',
#   'good',
#   'I',
#   'so',
#   "Cleopatra'",
#   "'The",
#   'my',
#   'will.',
#   'if',
#   'learn,',
#   'the',
#   'cheerfully',
#   'bettered',
#   'people',
#   'life',
#   'who',
#   'nothing',
#   'directed',
#   'does',
#   'stuff',
#   'work',
#   'family.',
#   'there',
#   'inspirational',
#   'never',
#   'stories',
#   'they',
#   'work',
#   'abroad,',
#   'is',
#   'inspirational',
#   'inspirational.',
#   'breathe',
#   'create',
#   'relate',
#   'apply',
#   'inspirational',
#   "Texas'",
#   'dream',
#   'performance',
#   'why',
#   'aspirations',
#   'hearing',
#   'on',
#   'inspirational',
#   'touch',
#   'just',
#   'this',
#   'that',
#   'hands-on',
#   'Jennifer',
#   'she',
#   'only',
#   'cash',
#   'be',
#   'then',
#   'the',
#   'inspirational',
#   'daring.',
#   "'Jesus",
#   'graduates',
#   'not',
#   'where',
#   'did',
#   'think',
#   'had',
#   'then',
#   "that's",
#   'I',
#   'Mr.',
#   'they',
#   'slightly',
#   'most',
#   'I',
#   'create,',
#   'this',
#   'rap,',
#   'dreams,',
#   'she',
#   'my',
#   'as',
#   'use',
#   'build',
#   'as',
#   'be',
#   "you'd",
#   'mentored',
#   'inspirational.',
#   'they',
#   "it's",
#   'upgrade',
#   'instructive',
#   "it's",
#   'inspirational',
#   'diverse.',
#   'emotional',
#   'I',
#   'I',
#   'I',
#   'the',
#   'inspirational.',
#   'give',
#   'Keith',
#   'Daniel',
#   'my',
#   'hopefully',
#   'what',
#   'often',
#   'the',
#   'Shirley',
#   'say,',
#   'most',
#   'inspirational',
#   'management.'],
#  'soul': ['into', 'with', 'was', 'made', 'and'],
#  'into': ['even',
#   'my',
#   'your',
#   'your',
#   'a',
#   'the',
#   'space',
#   'us',
#   'something',
#   'the',
#   'my',
#   'your',
#   'the',
#   'heaven.',
#   'your',
#   'the',
#   'the',
#   'the',
#   'the',
#   'real',
#   'the',
#   'the',
#   'shape',
#   'fantasy'],
#  'even': ['your', 'kids', 'if,', 'if'],
#  'smallest': ['acts.'],
#  'acts.': ['This'],
#  'This': ['is', 'is', 'is', 'CD'],
#  'is': ['the',
#   'waiting',
#   'not',
#   'something',
#   'during',
#   'impossible,',
#   'going',
#   'to',
#   'great',
#   'to',
#   'the',
#   'not',
#   'ever',
#   'not',
#   'sitting',
#   'someone',
#   'the',
#   'not',
#   'the',
#   'another',
#   'high',
#   'powered',
#   'what',
#   'in',
#   'shaped.',
#   'never',
#   'the',
#   'nothing',
#   'a',
#   'always',
#   'by',
#   'a',
#   'shining',
#   'too',
#   'happy',
#   'just',
#   'the',
#   'gone.',
#   'waiting',
#   'that',
#   'someone',
#   'that',
#   'possible.',
#   'that',
#   'the',
#   'the',
#   'the',
#   'full',
#   'natural,',
#   'infinite,',
#   'yes.',
#   'one',
#   'still,',
#   'because',
#   'a',
#   'always',
#   'worth',
#   'of',
#   'to',
#   'to',
#   'nothing',
#   'theatre.',
#   'our',
#   "man's",
#   'the',
#   'the',
#   'the',
#   'the',
#   'that',
#   'a',
#   'not',
#   'more',
#   'the',
#   'the',
#   'only',
#   'the',
#   'illuminated.',
#   'love',
#   'the',
#   'full',
#   'worth',
#   'a',
#   'always',
#   'to',
#   'firmly',
#   'something',
#   'the',
#   'by',
#   'the',
#   'hard',
#   'half-hearted',
#   'that',
#   'I',
#   'something',
#   'in',
#   'a',
#   'a',
#   'out',
#   'master',
#   'the',
#   'a',
#   'to',
#   'that',
#   'but',
#   'almost',
#   'today.',
#   'the',
#   'the',
#   'the',
#   'not',
#   'the',
#   'more',
#   'such',
#   'some',
#   'magic!',
#   'that',
#   'beautiful,',
#   'true,',
#   'great,',
#   'potential,',
#   'rare,',
#   'unique,',
#   'a',
#   'something',
#   'very',
#   'made',
#   'to',
#   'to',
#   'love',
#   'not',
#   'aspirational.',
#   'to',
#   'a',
#   'inspirational.',
#   'to',
#   'spent',
#   'so',
#   'the',
#   'there',
#   'in',
#   'written',
#   'not',
#   'in',
#   'fun,',
#   'always',
#   'inspirational',
#   'if',
#   'it',
#   'going',
#   'on',
#   'more',
#   'why',
#   'a',
#   'to',
#   'very',
#   'an',
#   'a',
#   'not',
#   'in',
#   'very',
#   'someone',
#   'an',
#   'a',
#   'a',
#   'dying',
#   'kind',
#   'built',
#   'not',
#   'that',
#   'an',
#   'the',
#   'illegal',
#   'the',
#   'the',
#   'fearless',
#   'depressing',
#   'educational,',
#   'the',
#   'not',
#   'very',
#   'an',
#   'just',
#   'to',
#   'still',
#   'uplifting',
#   'so',
#   "great!'",
#   "they've",
#   'so',
#   'still',
#   'crucial',
#   'the',
#   'useful',
#   'massively',
#   'not',
#   'so',
#   'directed'],
#  'the': ['secret',
#   'direction',
#   'wind,',
#   'life',
#   'one',
#   'impossible.',
#   'future;',
#   'present.',
#   'light.',
#   'word',
#   'only',
#   'only',
#   'heart,',
#   'greatest',
#   'greatest',
#   'best',
#   'freedom',
#   'sunshine',
#   'world.',
#   'shade',
#   'candle',
#   'mirror',
#   'harvest',
#   'seeds',
#   'world.',
#   'plan,',
#   'road',
#   'courage',
#   'highest',
#   'life',
#   'candle',
#   'rest',
#   'sun',
#   'shadows',
#   'light',
#   'way,',
#   'darkness',
#   'stars.',
#   'things',
#   'best',
#   'prettiest',
#   'rewards.',
#   'unlovable.',
#   'unpardonable.',
#   'unbelievable.',
#   'edges',
#   'tip',
#   'moon',
#   'stars.',
#   'choice',
#   'best',
#   'best',
#   'most',
#   'world',
#   'end',
#   'day',
#   'darkness',
#   'shoulders',
#   'one',
#   'difference.',
#   'world.',
#   'sun',
#   'universe',
#   'place',
#   'tide',
#   'possible',
#   'impossible.',
#   'soul.',
#   'only',
#   'world.',
#   'human',
#   'moment',
#   'energy',
#   'world',
#   'talking',
#   'soul',
#   'things',
#   'people',
#   'things',
#   'desert',
#   'one',
#   'natural',
#   'world',
#   'ground,',
#   'chill',
#   'most',
#   'skies,',
#   'leaping',
#   'blue',
#   'sense',
#   'future.',
#   'mind',
#   'whole',
#   'world',
#   'sky,',
#   'heroic',
#   'music',
#   'summer',
#   'day,',
#   'stars',
#   'vastness',
#   'heavens.',
#   'bitter',
#   'sweet.',
#   'adversities',
#   'past,',
#   'future.',
#   'soul,',
#   'ultimate',
#   'heart',
#   'power',
#   'world.',
#   'extraordinary',
#   'doors',
#   'sun',
#   'mountains!',
#   'ability',
#   'ability',
#   'expectations',
#   'outcome.',
#   'limits',
#   'possible',
#   'impossible.',
#   'world',
#   'strategy',
#   'game',
#   'narration',
#   'end',
#   'greatest',
#   'greatest',
#   'greatest',
#   'greatest',
#   'stars.',
#   'turtle',
#   'children',
#   'blueprints',
#   'fingers',
#   'rapture',
#   'winners',
#   'ones',
#   'truth',
#   'world.',
#   "spirit's",
#   'way.',
#   'smoke',
#   'impossible.',
#   'point',
#   'fountain',
#   'highest',
#   'heaven',
#   'fixed',
#   'storm',
#   'wind,',
#   'sail,',
#   'vessel.',
#   'root',
#   'depths',
#   'heart.',
#   'soul.',
#   'human',
#   'things',
#   'simple',
#   'marvelous.',
#   'fullest',
#   'future',
#   'course',
#   'United',
#   'city',
#   'United',
#   'clock',
#   'world.',
#   'New',
#   'people',
#   'beauty',
#   'influence',
#   'minerals,',
#   'leadership',
#   'things',
#   'public,',
#   'organizations',
#   'impossible.',
#   'stars.',
#   'beat',
#   'pulse',
#   'music',
#   'world',
#   'amazing',
#   'visionary',
#   'inspirational',
#   'civil',
#   'law',
#   'promise',
#   'wind.',
#   'almond',
#   'almond',
#   'wills',
#   'telescope',
#   'soul',
#   'Def',
#   "'80s",
#   'recollection',
#   'Almighty,',
#   'Creator',
#   'world.',
#   'end',
#   'end',
#   'day,',
#   'one',
#   'scheduling',
#   'dream',
#   'Seventies',
#   'Seventies',
#   'way',
#   'players',
#   'future',
#   'overwhelming',
#   'agreement',
#   'way',
#   'exciting',
#   'art',
#   'last',
#   'world',
#   'quality',
#   'teacher.',
#   'maximum',
#   'most',
#   'mother',
#   'most',
#   'world.',
#   'sound',
#   'most',
#   'most',
#   'beginning',
#   'only',
#   'only',
#   'entire',
#   'Tony',
#   'form',
#   'walls',
#   'consciousness',
#   'race',
#   'high',
#   'Sprint',
#   'money',
#   'Lord.',
#   'past',
#   'Muslim',
#   'sheer',
#   'words',
#   'soul.',
#   'last',
#   'imparting',
#   'dashboards,',
#   'steering',
#   'beauty',
#   'mechanics.',
#   'world,',
#   'poaching',
#   'great',
#   'great',
#   "Shrew'.",
#   'supreme',
#   'sands',
#   'sea',
#   'whole',
#   'door',
#   'key',
#   'key',
#   'door',
#   'time,',
#   'same',
#   'very',
#   'whole',
#   'world',
#   'world',
#   'actual',
#   'ear;',
#   'mind.',
#   'world,',
#   'tradition',
#   'right',
#   'main',
#   'audience',
#   'march',
#   'box',
#   'way',
#   'Inspirational.',
#   'evening',
#   'one',
#   'time,',
#   'ordinary',
#   'world',
#   'rules',
#   'music',
#   'end',
#   'seven',
#   'Houston',
#   'music.',
#   'idea',
#   'reality',
#   'business',
#   'world.',
#   'city',
#   '21st',
#   'matrix',
#   'big',
#   'country,',
#   'way',
#   'number',
#   'songs',
#   'appeal',
#   'election',
#   'positive',
#   'show',
#   'viewers,',
#   'show',
#   'song',
#   'way',
#   'speculative',
#   'inspirational',
#   'increasingly',
#   'house',
#   'day',
#   'years.',
#   'music',
#   'case,',
#   'reason',
#   'people',
#   'presidency',
#   'trust',
#   'most',
#   'only',
#   'present',
#   'future.',
#   'most',
#   'Job',
#   'sky,',
#   'limit',
#   'morning',
#   'words',
#   'chance',
#   'most',
#   'sweetest',
#   'album.',
#   'Designer',
#   'universe',
#   'souls',
#   'whole',
#   'epitome',
#   'forefront',
#   'same',
#   'end',
#   'attention',
#   'way',
#   'idea',
#   'White',
#   'belief',
#   'ugliness',
#   'whole',
#   'world.',
#   'world',
#   'toilet',
#   'locked',
#   'shops:',
#   'homily;',
#   "'momily'",
#   'inspirational',
#   'New',
#   'late',
#   'balance',
#   'studio',
#   '1984',
#   'presidency',
#   'closest',
#   'original',
#   'heart',
#   'untapped',
#   'incredibly',
#   'prints',
#   'economy',
#   'stuff',
#   'rhythm',
#   'main',
#   'British',
#   'physical',
#   'church,',
#   'musicians',
#   'way',
#   'time',
#   'most',
#   'question',
#   'reason'],
#  'secret': ['of'],
#  'of': ['success.',
#   'the',
#   'the',
#   'your',
#   'the',
#   'kindness,',
#   'you,',
#   'you.',
#   'spreading',
#   'candles',
#   'the',
#   'training,',
#   'your',
#   'victory',
#   'Time',
#   'a',
#   'who',
#   'difficulties',
#   'decision',
#   'the',
#   'itself.',
#   'giants.',
#   'our',
#   'our',
#   'every',
#   'imagination',
#   'every',
#   'the',
#   'him',
#   'good',
#   'that',
#   'the',
#   'duty.',
#   'your',
#   'magical',
#   'trees,',
#   'sky',
#   'those',
#   'joy',
#   'the',
#   'the',
#   'tomorrow',
#   'all',
#   'sincere',
#   'good',
#   'good',
#   'value.',
#   'love',
#   'inestimable',
#   'perception',
#   'one',
#   'others,',
#   'the',
#   'chess.',
#   'footage.',
#   'knowledge',
#   'learning',
#   'easy',
#   'thought,',
#   'a',
#   'your',
#   'your',
#   'another',
#   'living.',
#   'their',
#   'my',
#   'impossibility.',
#   'tears.',
#   'tomorrow,',
#   'good,',
#   'the',
#   'all',
#   'fertile',
#   'heartbeats.',
#   'mine.',
#   'the',
#   'our',
#   'the',
#   'history.',
#   'different',
#   'form',
#   'freedom.',
#   'someone',
#   'the',
#   'eagerness',
#   'me.',
#   'the',
#   'my',
#   'my',
#   'Rosa',
#   'Martin',
#   'the',
#   'America',
#   "God,'",
#   'others,',
#   'him',
#   'himself.',
#   'so',
#   'gratitude,',
#   'us',
#   'nothing.',
#   'stone.',
#   'the',
#   'talented',
#   'this,',
#   'days',
#   'those',
#   'people',
#   'the',
#   'the',
#   'time',
#   'wonder.',
#   'heaven',
#   'mysterious.',
#   'it',
#   'fiction.',
#   'life,',
#   'me',
#   'person.',
#   'education',
#   'aspiration.',
#   'our',
#   'flattery',
#   'giving',
#   'the',
#   'these',
#   'praise',
#   'construction,',
#   'it.',
#   'sporting',
#   'inspirational',
#   'time',
#   'the',
#   'it',
#   'who',
#   'inspirational',
#   'wildlife',
#   'aware',
#   'Christopher',
#   'Craig',
#   'the',
#   'the',
#   'his',
#   'the',
#   'the',
#   'us',
#   'course,',
#   'deafness',
#   'mankind.',
#   'feminism',
#   'power,',
#   'most',
#   'love',
#   'pop',
#   'times,',
#   'inspirational',
#   'struggle',
#   'success,',
#   'the',
#   'some',
#   'inclusiveness',
#   'being',
#   'magical,',
#   'street',
#   'killing',
#   'inspirational',
#   'the',
#   'times',
#   'public',
#   'America',
#   'done.',
#   'Barack',
#   "Cosplay'",
#   'the',
#   'music',
#   'space',
#   'science',
#   'artists',
#   'space,',
#   'what',
#   'sacred',
#   'the',
#   'albums',
#   'those',
#   'those',
#   'the',
#   'men',
#   'Nature',
#   'a',
#   'anything',
#   'an',
#   'what',
#   'people.',
#   'who',
#   'scientific',
#   'the',
#   'changing',
#   'brute',
#   'a',
#   'the',
#   'Westeros,',
#   'the',
#   'an',
#   'Guiness',
#   'course',
#   'his',
#   'American',
#   'the',
#   'looks',
#   'inspirational',
#   'the',
#   'the',
#   'the',
#   'Martin',
#   'things.',
#   'Miami,',
#   'the'],
#  'success.': ['I'],
#  'I': ["can't",
#   'can',
#   'choose',
#   'wake',
#   'can',
#   'choose',
#   'hated',
#   'said,',
#   'will',
#   'will',
#   'believe',
#   'believe',
#   'believe',
#   'believe',
#   'believe',
#   'believe',
#   'believe',
#   'went',
#   'felt',
#   'have',
#   '-',
#   'took',
#   'can',
#   'knew',
#   'would',
#   'believe',
#   'thank',
#   'create,',
#   'write',
#   'dwell',
#   'have',
#   'still',
#   'can',
#   'knew',
#   'believe',
#   'wanted',
#   'am',
#   'have',
#   'love',
#   'may',
#   'can',
#   "don't",
#   'believe',
#   "don't",
#   'know',
#   'am',
#   'am',
#   'think',
#   'did',
#   'ran',
#   'was',
#   'do.',
#   'inspire',
#   'inspire',
#   'inspire',
#   'inspired',
#   'took',
#   'celebrate',
#   'arise',
#   'love',
#   'believe',
#   'said',
#   "don't",
#   'went',
#   'now,',
#   'believe',
#   'am',
#   'am',
#   'have',
#   'have',
#   'believe',
#   'just',
#   'want',
#   'did',
#   'only',
#   "don't",
#   'was',
#   'got',
#   'was',
#   'stayed',
#   'used',
#   'had',
#   'can',
#   'have',
#   'always',
#   'think',
#   'think',
#   'think,',
#   "don't",
#   "don't",
#   'went',
#   'am.',
#   'view',
#   'think',
#   'worked',
#   'think',
#   'did',
#   'lived',
#   'breathed,',
#   'pray',
#   'think',
#   'think',
#   'think',
#   'look',
#   'look',
#   'want',
#   'picked,',
#   'used',
#   'used',
#   'found',
#   'am?',
#   'find',
#   'not',
#   'feel',
#   'feel,',
#   'get',
#   'want',
#   'hope',
#   'have',
#   'look',
#   'look',
#   'fell',
#   'would',
#   'look',
#   'like',
#   'believe',
#   'do',
#   "can't",
#   'find',
#   "don't",
#   'think',
#   'love',
#   'want',
#   'wrote',
#   'Kissed',
#   'met',
#   'was',
#   'wrote',
#   'thought,',
#   'want',
#   'have',
#   'think',
#   'am',
#   'am',
#   'can',
#   'really',
#   'thought',
#   'loved.',
#   "don't",
#   'just',
#   'love',
#   'did',
#   'just',
#   "wouldn't",
#   'call',
#   'wanted',
#   'approached',
#   'am',
#   'have',
#   'grew',
#   "hadn't",
#   'loved',
#   'was',
#   'had',
#   'found',
#   'loved',
#   'had',
#   'kinda',
#   'really',
#   'take',
#   'am',
#   'do',
#   'go',
#   'do',
#   'cannot',
#   'find',
#   'knew,',
#   'try',
#   'do',
#   'hear',
#   'am',
#   'am',
#   'think',
#   'get',
#   'can',
#   'see',
#   'absolutely',
#   'think',
#   'find',
#   'wish',
#   'head',
#   'find',
#   'get',
#   'go',
#   'call',
#   'love',
#   'just',
#   'listened',
#   'had',
#   'found',
#   'voted',
#   'have',
#   'always',
#   'think',
#   'had',
#   'do',
#   'pull',
#   'play',
#   'would',
#   'actually',
#   'started',
#   'think',
#   'grew',
#   'was',
#   'most',
#   'want',
#   'want',
#   'will',
#   'like',
#   'suppose',
#   'went',
#   'wanted'],
#  "can't": ['change', 'help', 'resist', 'see'],
#  'change': ['the',
#   'your',
#   'the',
#   'the',
#   'our',
#   'your',
#   'the',
#   'outer',
#   'your',
#   'with',
#   'in',
#   'lives.',
#   'it',
#   'their'],
#  'direction': ['of'],
#  'wind,': ['but', 'knowledge'],
#  'but': ['I',
#   'embrace',
#   'to',
#   'if',
#   'know',
#   'to',
#   'by',
#   'to',
#   'everyone',
#   'I',
#   'so',
#   'which,',
#   'do',
#   'let',
#   'the',
#   'a',
#   'a',
#   'a',
#   'we',
#   'not',
#   'that',
#   'that',
#   'the',
#   'knowledge',
#   'if',
#   'then',
#   'I',
#   'question,',
#   'be',
#   'up',
#   "it's",
#   'my',
#   "it's",
#   'you.',
#   'we',
#   'can',
#   'fear',
#   'for',
#   'for',
#   'the',
#   'they',
#   'as',
#   'Patti'],
#  'can': ['adjust',
#   'choose',
#   'and',
#   'catch',
#   'change',
#   'have',
#   'change',
#   'go;',
#   'be',
#   'help',
#   'shake',
#   'do',
#   'do.',
#   'go',
#   'achieve.',
#   'only',
#   'risk',
#   'be!',
#   'love!',
#   'accomplish!',
#   'change',
#   'do,',
#   'turn',
#   'bridge',
#   'truly',
#   'always',
#   'make',
#   'plant',
#   'take',
#   'accomplish.',
#   'go',
#   'never',
#   'do',
#   'command',
#   'mold',
#   'never',
#   'layer',
#   'get',
#   'give',
#   'build',
#   'relate',
#   'make',
#   'design',
#   'have',
#   'feel',
#   'be.',
#   'take',
#   'make',
#   'help',
#   'relate',
#   'really',
#   'be',
#   'send',
#   'continue',
#   'be'],
#  'adjust': ['my'],
#  'my': ['sails',
#   'destination.',
#   'humanity',
#   'life,',
#   'sunset',
#   'apple',
#   'life',
#   'hand',
#   'heart',
#   'life',
#   'only',
#   'friends;',
#   'staff.',
#   'nature',
#   'heart,',
#   'blood',
#   'mind.',
#   'sincere',
#   'eyes.',
#   'heart',
#   'whole',
#   'big',
#   "'job,'",
#   'career',
#   'music',
#   'big',
#   'first',
#   'music',
#   'parents',
#   'rent',
#   'breath',
#   'mother',
#   'life:',
#   'bio',
#   'themes',
#   'kingdom.',
#   'playlist',
#   'family.',
#   'life',
#   'radio',
#   'commitment',
#   'own',
#   'work',
#   'audience',
#   'success',
#   'job.',
#   'relationship',
#   'lyric',
#   'parents',
#   'football',
#   'junior',
#   'eyes',
#   'confidence',
#   'friends',
#   'performance',
#   'writing',
#   'plot,',
#   'husband.',
#   'eyes',
#   'life',
#   'inspirational',
#   'mother',
#   'life.',
#   'children.'],
#  'sails': ['to'],
#  'to': ['always',
#   'accept',
#   'see',
#   'be',
#   'fill',
#   'be',
#   'do',
#   'do',
#   'love',
#   'continue',
#   'make',
#   'feel',
#   'deny',
#   'survive,',
#   'thrive;',
#   'do',
#   'what',
#   'carry',
#   'add',
#   'my',
#   'be',
#   'something',
#   'press',
#   'your',
#   'utter',
#   'live',
#   'grab',
#   'the',
#   'be',
#   'those',
#   'discover',
#   'be',
#   'live',
#   'go',
#   'him',
#   'overcome.',
#   'what',
#   'be',
#   'improve',
#   'pieces,',
#   'which',
#   'you,',
#   'warm',
#   'be',
#   'surrender',
#   'the',
#   'grow',
#   'create',
#   'the',
#   'come.',
#   'inspire',
#   'the',
#   'be.',
#   'the',
#   'man',
#   'me',
#   'persist',
#   'start',
#   'discover',
#   'go',
#   'me',
#   'create,',
#   'overcome,',
#   'endure,',
#   'transform,',
#   'love',
#   'be',
#   'be',
#   'the',
#   'the',
#   'be',
#   'really',
#   'do.',
#   'great',
#   'the',
#   'that',
#   'do',
#   'do.',
#   'sprout.',
#   'waste',
#   'change',
#   'know',
#   'me',
#   'be',
#   'somebody',
#   'preserve',
#   'our',
#   'live',
#   'the',
#   'try',
#   'others.',
#   'change',
#   'happen',
#   'have',
#   'inspire',
#   'trust',
#   'build',
#   'be',
#   'want',
#   'succeed.',
#   'dance',
#   'begin',
#   'write',
#   'truth,',
#   'ask.',
#   'take',
#   'get',
#   'the',
#   'me',
#   'learn',
#   'the',
#   'me.',
#   'offer',
#   'the',
#   'make',
#   'stand',
#   'stoop',
#   'get',
#   'promotion',
#   'pass;',
#   'become',
#   'us',
#   'be',
#   'be',
#   'be',
#   'make',
#   'open',
#   'me.',
#   'you',
#   'you',
#   'pass!',
#   'help',
#   'help',
#   'control',
#   'oust',
#   'realize',
#   'inspire',
#   'get',
#   'be',
#   'be',
#   'us',
#   'make',
#   'impose',
#   'have',
#   'make',
#   'do',
#   'bring',
#   'find',
#   'the',
#   'be',
#   'become',
#   'know,',
#   'me',
#   'me.',
#   'a',
#   'one',
#   'the',
#   'younger',
#   'me.',
#   'God',
#   'look',
#   'open,',
#   'see.',
#   'that.',
#   'something:',
#   'get',
#   'do,',
#   'pick',
#   'get',
#   'create',
#   'feel',
#   'see',
#   'me.',
#   'eat',
#   'make',
#   'be',
#   'a',
#   'think.',
#   'think.',
#   'be',
#   'think',
#   'that',
#   'make',
#   'be',
#   'take',
#   'change',
#   'them',
#   'representing',
#   'a',
#   'Nashville',
#   'finish.',
#   'be',
#   'me.',
#   'be,',
#   'them',
#   'your',
#   'making',
#   'the',
#   'carve',
#   'be',
#   'bring',
#   'be',
#   'engineering',
#   'make',
#   'be',
#   'be',
#   'get',
#   'do',
#   'creating',
#   'fear',
#   'eavesdrop.',
#   'tell',
#   'see',
#   'me',
#   'me.',
#   'find',
#   'connect',
#   'are',
#   'no',
#   'D.C.',
#   'memorialize',
#   'make',
#   'the',
#   'get',
#   'do',
#   'the',
#   'the',
#   'be',
#   'be,',
#   'keep',
#   'me.',
#   'look',
#   'us.',
#   'a',
#   'follow',
#   'the',
#   'the',
#   'university.',
#   'sing',
#   'declare',
#   'experience',
#   'learn',
#   'record',
#   'write',
#   'work',
#   'be',
#   'put',
#   'do',
#   'dream',
#   'make',
#   'take',
#   'do',
#   'me.',
#   'miss.',
#   'see',
#   'women,',
#   'be',
#   'a',
#   'the',
#   'me,',
#   'find',
#   'building',
#   'the',
#   'him,',
#   'a',
#   'the',
#   'begin',
#   'motivate',
#   'change',
#   'my',
#   'me',
#   'get',
#   'add',
#   'do',
#   'be',
#   'look',
#   'play',
#   'be',
#   'what',
#   'do'],
#  'always': ['reach',
#   'toward',
#   'put',
#   'gives',
#   'just',
#   'looked',
#   'through.',
#   'believed,',
#   'give',
#   'desire',
#   'free',
#   'the',
#   'an',
#   'coming',
#   'felt',
#   'thought',
#   'remain',
#   'standing',
#   'draw',
#   'been',
#   'give',
#   'rather',
#   'like',
#   'desire'],
#  'reach': ['my', 'of', 'should'],
#  'destination.': ['We', 'As'],
#  'We': ['must',
#   'know',
#   "can't",
#   'can',
#   'can',
#   'must',
#   'clarify,',
#   'know',
#   'relish',
#   'have',
#   'convince',
#   'are',
#   'sing',
#   'are',
#   'work',
#   'can',
#   'all',
#   'have'],
#  'must': ['let',
#   'focus',
#   'never',
#   'not',
#   'go',
#   'do',
#   'partake',
#   'live',
#   'hunger',
#   'inevitably',
#   'humanize'],
#  'let': ['go', 'go.', 'us', 'your', 'life', 'it'],
#  'go': ['of',
#   'beyond',
#   'through',
#   'as',
#   'to',
#   'beyond',
#   'wrong.',
#   "along'",
#   'full-on',
#   'out',
#   'out'],
#  'life': ['we',
#   'is',
#   'to',
#   'of',
#   'as',
#   'lightly',
#   'and',
#   'creatively.',
#   'are',
#   'on',
#   'by',
#   'is',
#   'was',
#   'happen',
#   '-',
#   'people',
#   'is',
#   'gushes',
#   'many',
#   'is',
#   'story',
#   '-',
#   'is',
#   'was'],
#  'we': ['have',
#   'must',
#   'chase',
#   'can',
#   'think,',
#   'become.',
#   'are,',
#   'may',
#   'express',
#   'must',
#   'are',
#   'do',
#   'have.',
#   'seek',
#   'somehow',
#   'believe',
#   'can',
#   'did',
#   'are',
#   'would',
#   'wish.',
#   'love',
#   'are.',
#   'are',
#   'would',
#   'see',
#   'encounter',
#   'can',
#   'can',
#   'get,',
#   'can',
#   'give,',
#   'need',
#   'should',
#   'face',
#   'achieve',
#   "don't",
#   'can',
#   'are',
#   'feel',
#   'must',
#   'are',
#   'are.',
#   'obeyed',
#   'kneel',
#   'ever',
#   'possessed.',
#   'need',
#   'are',
#   'admire',
#   'have.',
#   'must',
#   'will',
#   'have',
#   'have',
#   'could',
#   'had',
#   'launched',
#   'lived'],
#  'have': ['planned,',
#   'a',
#   'a',
#   'dedication',
#   'been.',
#   'seen',
#   'learned',
#   'always',
#   'seen',
#   'scars',
#   'to',
#   'a',
#   'to',
#   'it',
#   'to',
#   'far',
#   'looked',
#   'put',
#   'now',
#   'been',
#   'to',
#   'to',
#   'people',
#   'people',
#   'a',
#   'to',
#   'been',
#   'made',
#   'thought',
#   'a',
#   'never',
#   'been',
#   'created',
#   'to',
#   'been',
#   'a',
#   'an',
#   'no',
#   'to',
#   'reached',
#   'been',
#   'it',
#   'experienced',
#   'enough',
#   'done',
#   'amazing',
#   'led',
#   'been',
#   'been'],
#  'planned,': ['so'],
#  'so': ['as',
#   'with',
#   'that',
#   'are',
#   'with',
#   'many',
#   'many',
#   'many',
#   'fresh',
#   'interesting',
#   'much,',
#   'accessible',
#   'great',
#   'inspirational.',
#   'great',
#   'inspirational',
#   'inspirational.',
#   'much',
#   'motivating',
#   'strong',
#   "nothing's",
#   'if',
#   'hard.',
#   'inspirational,',
#   'inspirational,',
#   'inspirational',
#   'inspirational.'],
#  'as': ['to',
#   'a',
#   'long',
#   'you',
#   'far',
#   'your',
#   'though',
#   'high',
#   'it',
#   'the',
#   'it',
#   'far',
#   'you',
#   'they',
#   'thick',
#   'an',
#   'resilient',
#   'the',
#   'a',
#   'well.',
#   'Snoop',
#   'a',
#   'a',
#   'the',
#   'its',
#   'an',
#   'a',
#   'inspirational',
#   'an',
#   'the',
#   'Marilyn',
#   'a',
#   'a',
#   'a',
#   'well.',
#   'gloriously',
#   'that',
#   'you',
#   'far',
#   'putting',
#   'far',
#   'inspirational,',
#   'successful',
#   'her',
#   'an',
#   'an',
#   'I',
#   'if',
#   'inspirational',
#   'Paul',
#   'a',
#   'well,',
#   'he',
#   'well',
#   'nutritive.',
#   'executive',
#   'he',
#   'a',
#   'well',
#   'an',
#   'an'],
#  'accept': ['the', 'the'],
#  'one': ['that',
#   'pen,',
#   'child,',
#   'teacher',
#   'else',
#   'less',
#   'within.',
#   'always',
#   'would',
#   'of',
#   'warm',
#   'item.',
#   'little',
#   'good',
#   'exquisite',
#   'needs',
#   'defines',
#   'commonality',
#   'strand',
#   'day',
#   'that',
#   'feel',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of'],
#  'that': ['is',
#   'we',
#   'comes',
#   'our',
#   'reflects',
#   'you',
#   'the',
#   'laughing',
#   'happy',
#   'tomorrow',
#   'your',
#   'way.',
#   'has',
#   'is',
#   'the',
#   'nobody',
#   'reveals',
#   'you',
#   'moment',
#   'tomorrow',
#   'somewhere',
#   'if',
#   'we',
#   'right',
#   'is',
#   'person.',
#   'truth,',
#   'truth',
#   'overwhelm',
#   'whatever',
#   'every',
#   'music,',
#   'I',
#   'help',
#   'most.',
#   'of',
#   'comes',
#   'clutched',
#   'makes',
#   'stillness',
#   'which',
#   'I',
#   "I'm",
#   'we',
#   'quite',
#   'produces',
#   'never',
#   'people',
#   'any',
#   "it's",
#   'it',
#   "you're",
#   'in',
#   'I',
#   'he',
#   'he',
#   'he',
#   'he',
#   'life',
#   'one',
#   'both',
#   'they',
#   'are',
#   'it',
#   'raises',
#   'God',
#   'is',
#   'is',
#   'in',
#   'job,',
#   "wasn't",
#   'was',
#   'we',
#   'has',
#   'teenagers',
#   'the',
#   'is',
#   'a',
#   "there's",
#   'ultimately',
#   'changed',
#   'I',
#   'I',
#   'can',
#   'I',
#   'all',
#   'state',
#   'at',
#   'I',
#   'they',
#   'will',
#   'says',
#   'not',
#   'Americans',
#   "I've",
#   'they',
#   'going',
#   "I'm",
#   'lift',
#   'everybody',
#   'effort',
#   'want',
#   'from',
#   'the',
#   'I',
#   'the',
#   "it's",
#   'Paris',
#   'just',
#   'have',
#   'you',
#   'I',
#   'I',
#   'ever',
#   'was',
#   'the',
#   'hard',
#   "it's",
#   "I'm",
#   'allows',
#   'are',
#   'every',
#   'in',
#   'every',
#   'is',
#   'would',
#   'human',
#   'I',
#   'Abbey',
#   'have'],
#  'waiting': ['for', 'to', 'for', 'to', 'for', 'to'],
#  'for': ['us.',
#   'the',
#   'the',
#   'it',
#   'the',
#   'me',
#   'me,',
#   'that',
#   'our',
#   'this',
#   'the',
#   'the',
#   'everything',
#   'God,',
#   'lifetimes',
#   'it.',
#   'the',
#   'sure;',
#   'I',
#   'everything,',
#   'divine',
#   'the',
#   'president',
#   'the',
#   'all',
#   'you',
#   'the',
#   'Northern',
#   'everybody:',
#   'young',
#   'the',
#   'the',
#   'a',
#   'it',
#   'their',
#   'some',
#   'what',
#   'me.',
#   'when',
#   'inspirational',
#   'me.',
#   'a',
#   'Gaga.',
#   'the',
#   'everyone.',
#   'help.',
#   'subject',
#   'actual',
#   '100',
#   'me',
#   'a',
#   'your',
#   'more',
#   'too',
#   'my',
#   'paps',
#   'the',
#   'a',
#   'me',
#   '10',
#   'the',
#   'good',
#   'me.',
#   'a',
#   'the',
#   'its',
#   'science',
#   'kids,',
#   'my'],
#  'us.': ['Start', 'Ford'],
#  'Start': ['by'],
#  'by': ['doing',
#   'the',
#   'the',
#   'them.',
#   'being',
#   'its',
#   'its',
#   'standing',
#   'going',
#   'sunbeams.',
#   'changing',
#   'acts',
#   'ideas',
#   'virtue',
#   "God's",
#   'our',
#   'which',
#   'reinvention.',
#   'friends',
#   'its',
#   'Mies',
#   'with',
#   'George',
#   'putting',
#   'strangers',
#   'images',
#   'complex',
#   'heart,',
#   'things',
#   'the',
#   'someone'],
#  'doing': ["what's", 'the', 'a', 'it.'],
#  "what's": ['necessary;', 'possible;', 'a'],
#  'necessary;': ['then'],
#  'then': ['do', 'you', 'he', "it's", 'at', 'it', 'I', 'I', 'Susan'],
#  'do': ["what's",
#   'what',
#   'great',
#   'so',
#   'the',
#   'with',
#   'anything;',
#   'so',
#   'not',
#   'what',
#   'that',
#   'that.',
#   'what',
#   'shy',
#   'love',
#   'that.',
#   'like',
#   'not',
#   'creatively.',
#   'think',
#   'things',
#   'a',
#   'sensible',
#   'something'],
#  'possible;': ['and'],
#  'suddenly': ['you'],
#  'you': ['are',
#   'postpone',
#   'design',
#   'believe',
#   'do.',
#   "haven't",
#   'find',
#   'change',
#   'can',
#   'and',
#   'reap',
#   'plant.',
#   'can',
#   'start.',
#   'need',
#   'have',
#   'always',
#   'do,',
#   'must',
#   'must',
#   'think',
#   'cannot',
#   'believe',
#   'miss',
#   'will',
#   'might',
#   'treat',
#   'will',
#   'can',
#   'believe,',
#   'can',
#   'get',
#   'could',
#   'are',
#   "don't",
#   'can',
#   'can',
#   'can',
#   'together,',
#   'do',
#   'God',
#   'can',
#   'look',
#   'are',
#   'are;',
#   'accept',
#   'never',
#   'anywhere.',
#   'can.',
#   'most',
#   'think',
#   'carry',
#   'attempt',
#   'knew',
#   'could',
#   'really',
#   'can',
#   'left',
#   'please',
#   'at',
#   'want',
#   'to',
#   'want',
#   'have',
#   'expect',
#   'know,',
#   'could',
#   'could',
#   'know',
#   'say',
#   'as',
#   'as',
#   'vividly',
#   'have',
#   'look',
#   'can',
#   'a',
#   'want',
#   'know',
#   'either',
#   'can',
#   'the',
#   'how',
#   'how',
#   'realize',
#   'can',
#   'perhaps',
#   'have',
#   'should',
#   'have',
#   'and',
#   "wouldn't",
#   "shouldn't",
#   'around.',
#   'know',
#   'would',
#   'to',
#   'something',
#   'just'],
#  'are': ['doing',
#   'two',
#   'no',
#   'only',
#   'the',
#   'the',
#   'is',
#   'all',
#   'now.',
#   'capable',
#   'influencing',
#   'like',
#   'and',
#   'to',
#   'those',
#   'the',
#   'the',
#   'the',
#   'nothing.',
#   'always',
#   'thoroughly',
#   'certain',
#   'extraordinary',
#   'often',
#   'here',
#   'full',
#   'many',
#   'concealed',
#   'most',
#   'all',
#   'glimpses',
#   'challenging',
#   'inspirational.',
#   'power',
#   'magnifying',
#   'inspirational.',
#   'our',
#   'human',
#   'walking',
#   'a',
#   'so',
#   'thousands',
#   'stories',
#   'inspirational,',
#   'a',
#   'inspirational',
#   'answering',
#   'a',
#   'less',
#   'downright',
#   'teaching'],
#  'impossible.': ['Happiness', 'Happiness', 'There', 'Men', 'A', "I'm"],
#  'Happiness': ['is', 'never', 'is', 'resides', 'is'],
#  'not': ['something',
#   'to',
#   'merely',
#   'attainable,',
#   'what',
#   'to',
#   'be',
#   'stay',
#   'hang',
#   'in',
#   'in',
#   'know',
#   'keep',
#   'appreciate',
#   'only',
#   'a',
#   'one',
#   'fail?',
#   'afraid',
#   'a',
#   'by',
#   'that',
#   'a',
#   'good',
#   'too',
#   'be',
#   'be',
#   'entangled',
#   'ignorance',
#   'to',
#   'an',
#   'just',
#   'here',
#   'here',
#   'only',
#   'only',
#   'in',
#   'worth',
#   'patter',
#   'make',
#   'be',
#   'come',
#   'so',
#   'only',
#   'only',
#   'an',
#   'aspirational.',
#   'get',
#   'a',
#   'know,',
#   'like',
#   'to',
#   'trying',
#   'only',
#   'only',
#   'him,',
#   'an',
#   'administration'],
#  'something': ['you',
#   'you',
#   'bigger',
#   'in',
#   'incredible',
#   'from',
#   'in',
#   'of',
#   'inspirational',
#   'one',
#   'like',
#   'that',
#   'that',
#   'that',
#   'out',
#   'positive',
#   'negative.',
#   'more',
#   'that',
#   'that',
#   'that',
#   'from',
#   'from',
#   'of',
#   'inspirational'],
#  'postpone': ['for'],
#  'future;': ['it'],
#  'it': ['is',
#   'yet,',
#   'and',
#   'shows',
#   'shows',
#   'was',
#   'that',
#   'is',
#   'seems',
#   'is',
#   'hides',
#   'will',
#   'will.',
#   'arrives',
#   'puts',
#   'is',
#   'meaning',
#   'into',
#   'is,',
#   'becomes',
#   'becomes',
#   'keep',
#   'will',
#   "doesn't",
#   'works',
#   'is',
#   'in',
#   "doesn't",
#   'is',
#   'is',
#   'sounds',
#   'because',
#   'was',
#   'to',
#   'is',
#   'might',
#   "doesn't",
#   'is',
#   'works,',
#   'has',
#   'as',
#   'be',
#   'is',
#   'in',
#   'something',
#   "can't",
#   'so',
#   'had',
#   'is',
#   'is;',
#   'for',
#   'is',
#   'with',
#   'takes',
#   'has',
#   'belonged,',
#   'is',
#   'changed,',
#   'in',
#   'more',
#   '-',
#   'there',
#   'at',
#   'is',
#   'will',
#   'for',
#   'was',
#   'what',
#   'is.',
#   'conversational.',
#   'opened',
#   'would'],
#  'design': ['for', 'is', 'your'],
#  'present.': ['It'],
#  'It': ['is',
#   'will',
#   'is',
#   'is',
#   'hopes',
#   'looks',
#   'is',
#   'seems',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'pricks',
#   'would',
#   "doesn't",
#   'has',
#   'was',
#   'takes',
#   'really',
#   'means',
#   'actually',
#   'fills',
#   'was',
#   'would',
#   'is'],
#  'during': ['our'],
#  'our': ['darkest',
#   'today',
#   'children',
#   'gratitude,',
#   'future',
#   'dreams',
#   'lives,',
#   'works',
#   'deeds',
#   'hands.',
#   'lives.',
#   'wits',
#   'way',
#   'footage,',
#   'capacity',
#   'suffering.',
#   'heroes,',
#   'heritage',
#   'cultural,',
#   'power',
#   'presence.',
#   'necks',
#   'fears,',
#   'compartmentalized',
#   'hearts',
#   'country',
#   'fans',
#   'better',
#   'lives.',
#   'blood',
#   'cities',
#   'whole',
#   'senators.',
#   'noblest',
#   'attitudes'],
#  'darkest': ['moments'],
#  'moments': ['that', 'of', 'when'],
#  'focus': ['to', 'or'],
#  'see': ['the',
#   'the',
#   'one',
#   'far',
#   'countries',
#   'it',
#   'women',
#   "'Senna',",
#   'someone',
#   'the',
#   'a',
#   'an',
#   'that',
#   'that'],
#  'light.': ['Try'],
#  'Try': ['to', 'to'],
#  'be': ['a',
#   'truly',
#   'the',
#   'lighted',
#   'shortened.',
#   'going',
#   'a',
#   'among',
#   'what',
#   'defined',
#   'right',
#   'known.',
#   'average',
#   'exactly',
#   'that',
#   'greater',
#   'like',
#   'still,',
#   'still',
#   'beautiful',
#   'an',
#   'inspired.',
#   'like',
#   'like',
#   'yourself.',
#   'the',
#   'motivational',
#   'fun',
#   'inspired.',
#   'doing',
#   'to',
#   'to',
#   'in',
#   'admired,',
#   'defeat.',
#   'offended...',
#   'nice',
#   'very',
#   'featured',
#   'helping',
#   'a',
#   'underestimated,',
#   'called',
#   'still.',
#   'told',
#   'inspirational.',
#   'quite',
#   'more',
#   'told,',
#   'made',
#   'inspirational.',
#   'people',
#   'inspirational.',
#   'inspirational',
#   'inspirational',
#   'inspirational.',
#   'surrounded',
#   'reckoned',
#   'majestic,',
#   'an',
#   'wonderfully',
#   'an',
#   'around'],
#  'a': ['rainbow',
#   'small',
#   'mighty',
#   'large',
#   'door.',
#   'tree',
#   'long',
#   'better',
#   'single',
#   "champion.'",
#   'dream,',
#   'lot.',
#   'winner.',
#   'leaf.',
#   'few',
#   'failure.',
#   'butterfly,',
#   'fruit',
#   'wood',
#   'gentle',
#   'tight',
#   'minute',
#   'single',
#   'piece',
#   'well.',
#   'kite,',
#   'new',
#   'new',
#   'new',
#   'new',
#   'man',
#   'different',
#   'divine',
#   'living;',
#   'life.',
#   'greeting',
#   'football',
#   'big',
#   'seed',
#   'flower,',
#   'bit',
#   'smile',
#   'dream',
#   'great',
#   'great',
#   'ship',
#   'new',
#   "man's",
#   'heaven',
#   'product,',
#   'theory,',
#   'meaning,',
#   'little',
#   'radiance.',
#   'single',
#   'few',
#   'finite',
#   'different',
#   'different',
#   'moment',
#   'fleeting',
#   'frozen',
#   'vital',
#   'great',
#   'place',
#   'good',
#   'winning',
#   'better',
#   'professional',
#   'motivational',
#   'kiss',
#   'veil.',
#   'fairy',
#   'century',
#   'mere',
#   'high',
#   'thousand',
#   'loftier',
#   'little',
#   'person,',
#   'rapper.',
#   "child's",
#   'child',
#   'luxury',
#   'new',
#   'page-turning',
#   'stepping',
#   'teacher,',
#   'very',
#   'homemaker.',
#   "'we'",
#   'blessedness',
#   'gallant',
#   'very',
#   'message',
#   'building',
#   'die-hard',
#   'massive',
#   'great',
#   'bit',
#   'kid.',
#   'school',
#   'list',
#   'difference',
#   'month.',
#   'path',
#   'retelling',
#   'hopeful',
#   'passion',
#   'great',
#   'script',
#   'good',
#   'new',
#   'tap-dancing',
#   'complete',
#   'hailstorm.',
#   'slide',
#   'small',
#   'professional',
#   'big',
#   'certain',
#   'certain',
#   'positive,',
#   'gift',
#   'chance',
#   'lot',
#   'spiritual',
#   'great',
#   'strong',
#   'great',
#   'real',
#   'kind',
#   'natural',
#   'movie',
#   'film',
#   'call',
#   'positive,',
#   'glorious',
#   'networking',
#   'special',
#   'desire',
#   'lot',
#   'costume.',
#   'girl',
#   'shower,',
#   'great',
#   'younger',
#   'situation',
#   'hundred',
#   'reply,',
#   'trip',
#   'gay',
#   'really',
#   'Gospel',
#   'bookless',
#   'good',
#   'teacher.',
#   'lot',
#   'day',
#   'breath.',
#   'disciplined',
#   'professional,',
#   'diverse',
#   'friend',
#   'startling',
#   'keyboard,',
#   'movie,',
#   'movie,',
#   'whole,',
#   'personal',
#   'force',
#   'halt,',
#   'pizza',
#   'lot',
#   'creative',
#   'show',
#   '20',
#   'superhero.',
#   'woman',
#   'lot',
#   'lot',
#   'writer',
#   'big',
#   'few',
#   'great',
#   'very',
#   'Liberty',
#   'very',
#   'rational',
#   'huge'],
#  'rainbow': ['in'],
#  'in': ["someone's",
#   'life',
#   'front',
#   'comparison',
#   'the',
#   'pink.',
#   'kissing,',
#   'being',
#   'miracles.',
#   'yourself',
#   'your',
#   'others,',
#   'ourselves.',
#   'the',
#   'others.',
#   'season',
#   'a',
#   'his',
#   'possessions,',
#   'gold,',
#   'the',
#   'ourselves,',
#   'life.',
#   'our',
#   'the',
#   'you.',
#   'the',
#   'possibility.',
#   'the',
#   'not',
#   'the',
#   'the',
#   'return,',
#   'your',
#   'the',
#   'sorrow',
#   'joy',
#   'its',
#   "God's",
#   'service?',
#   'the',
#   'the',
#   'plants,',
#   'animals,',
#   'man.',
#   'order',
#   'the',
#   'focus',
#   'life',
#   'my',
#   'my',
#   'our',
#   'the',
#   'Manchester',
#   'the',
#   'living',
#   'yesterday,',
#   'tomorrow.',
#   'soul',
#   'a',
#   'the',
#   'this',
#   'Ireland',
#   'favour',
#   'a',
#   'every',
#   'the',
#   'my',
#   'charge',
#   'his',
#   'our',
#   'the',
#   'the',
#   'their',
#   'the',
#   'Africa.',
#   'high',
#   'Ocean',
#   'your',
#   'the',
#   'small',
#   'letters',
#   'the',
#   'the',
#   'the',
#   'the',
#   'positions',
#   'the',
#   'my',
#   'the',
#   'our',
#   'terms',
#   'the',
#   'the',
#   'all',
#   'person',
#   'different',
#   'trekking',
#   'American',
#   'and',
#   'Australia.',
#   'for',
#   'that',
#   'London!',
#   'a',
#   'With',
#   'the',
#   'Theatre',
#   'a',
#   'that',
#   'my',
#   'front',
#   "Obama's",
#   'the',
#   'the',
#   'Japan,',
#   'church',
#   'the',
#   '2008',
#   "'92,",
#   'England,',
#   'this',
#   'the',
#   'power',
#   'politics.',
#   'terms',
#   'a',
#   'a',
#   'the',
#   'my'],
#  "someone's": ['cloud.'],
#  'cloud.': ['From'],
#  'From': ['a', 'what', 'its'],
#  'small': ['seed', 'letters', 'tree,', 'thing'],
#  'seed': ['a', 'and'],
#  'mighty': ['trunk'],
#  'trunk': ['may'],
#  'may': ['grow.', 'be.', 'alight', 'be', 'come', 'always', 'preserve'],
#  'grow.': ['Nothing'],
#  'Nothing': ['is', 'is', 'makes'],
#  'impossible,': ['the'],
#  'word': ['itself', 'from'],
#  'itself': ['says', 'in', 'more'],
#  'says': ["'I'm", "'grunge'", 'no'],
#  "'I'm": ["possible'!"],
#  "possible'!": ['Your'],
#  'Your': ['work', 'present', 'personal', 'big', 'ordinary', 'heart'],
#  'work': ['is',
#   'is',
#   'and',
#   'to',
#   'and',
#   'to',
#   'ethic.',
#   'had',
#   'that',
#   'with'],
#  'going': ['to', 'wrong.', 'beyond', 'to', 'to', 'to', 'to'],
#  'fill': ['a'],
#  'large': ['part', 'for'],
#  'part': ['of', 'ballet.', 'battleground,', 'playground.', 'and', 'of'],
#  'life,': ['and', 'not', 'no', 'your', 'and', 'a', 'and'],
#  'only': ['way',
#   'way',
#   'plateaus,',
#   'walls.',
#   'be',
#   'day.',
#   'journey',
#   'the',
#   'way',
#   'darkness',
#   'in',
#   'real',
#   'sporadic',
#   'to',
#   'beauty,',
#   'love.',
#   'hopes',
#   'love',
#   'did',
#   'space',
#   'space.',
#   'laugh',
#   'laugh',
#   'thing',
#   'serves',
#   'for',
#   'God',
#   'place',
#   'the',
#   'improves',
#   'was'],
#  'way': ['to',
#   'to',
#   'out',
#   'we',
#   'to',
#   'of',
#   'all',
#   'for',
#   'of',
#   'people',
#   'back',
#   'and',
#   'that'],
#  'truly': ['satisfied', 'love', 'inspirational.'],
#  'satisfied': ['is'],
#  'what': ['you',
#   'you',
#   'lies',
#   'lies',
#   'we',
#   'we',
#   'people',
#   'we',
#   'we',
#   'you',
#   'they',
#   'your',
#   'it',
#   'we',
#   'we',
#   'your',
#   'we',
#   'we',
#   'you',
#   'I',
#   'achievement',
#   'the',
#   'we',
#   'you',
#   'they',
#   'they',
#   "I'm",
#   'it',
#   'whatever',
#   'space',
#   'future',
#   "I'm",
#   'did',
#   "we're",
#   'it',
#   'I',
#   'our',
#   'was'],
#  'believe': ['is',
#   'in',
#   'that',
#   'in',
#   'in',
#   'that',
#   'that',
#   'in',
#   'in',
#   'in',
#   'that',
#   'in',
#   "there's",
#   'every',
#   'it',
#   'in',
#   'that',
#   'in'],
#  'great': ['work.',
#   'work',
#   'you',
#   'thoughts.',
#   'book',
#   'thinker',
#   'thing',
#   'deeds.',
#   'men.',
#   'melting',
#   'favours',
#   'or',
#   'change',
#   'deal,',
#   'baton',
#   'theater',
#   'and',
#   'opportunity,',
#   'to',
#   'education.',
#   'work',
#   'job',
#   'role',
#   'gifts'],
#  'work.': ['And'],
#  'And': ['the',
#   'what',
#   'the',
#   'if',
#   'above',
#   "that's",
#   'when',
#   'is',
#   'deserve',
#   'then',
#   'the',
#   'President',
#   'you',
#   'now,',
#   'if',
#   'as'],
#  'love': ['what',
#   'the',
#   'means',
#   'the',
#   'tell',
#   'from',
#   'as',
#   'and',
#   'and',
#   'today!',
#   'and',
#   'those',
#   'the',
#   'enough,',
#   'taking',
#   '-',
#   'to',
#   'and',
#   'to',
#   'inspirational',
#   'horses.',
#   'a'],
#  'do.': ['If', 'I', 'You', 'Love', 'Where', 'I'],
#  'If': ['you',
#   'opportunity',
#   'you',
#   'you',
#   'I',
#   'we',
#   'the',
#   'a',
#   'there',
#   'the',
#   'you',
#   'you',
#   'someone',
#   'I',
#   'you',
#   "it's",
#   'not,',
#   'anything',
#   'my',
#   'not'],
#  "haven't": ['found'],
#  'found': ['it', 'it', 'I', 'him'],
#  'yet,': ['keep'],
#  'keep': ['looking.', 'pace', 'me', 'evolving.', 'everything'],
#  'looking.': ["Don't"],
#  "Don't": ['settle.', 'judge', 'limit'],
#  'settle.': ['As'],
#  'As': ['with', 'we', 'knowledge', 'people', 'long'],
#  'with': ['all',
#   'some',
#   'him.',
#   'what',
#   'itself.',
#   'whom',
#   'all',
#   'wings.',
#   'great',
#   'his',
#   'the',
#   'others',
#   'our',
#   'truth',
#   'today!',
#   'oneself,',
#   'a',
#   'my',
#   'inspirational',
#   'an',
#   'its',
#   'just',
#   "'Casino",
#   'an',
#   'a',
#   'the',
#   'overly',
#   'you.',
#   'your',
#   'God.',
#   'Taylor',
#   'my',
#   'my',
#   'us,',
#   'Simon',
#   'Drake',
#   'early',
#   'Bruce'],
#  'all': ['matters',
#   'intertwined.',
#   'times,',
#   'the',
#   'boundaries.',
#   'your',
#   'the',
#   'special',
#   'creation.',
#   'things',
#   'knowledge.',
#   'of',
#   'things,',
#   'her',
#   'about',
#   "life's",
#   'the',
#   'inspirational',
#   'human',
#   'the',
#   'the',
#   'songs,',
#   'the',
#   'its',
#   'obviously'],
#  'matters': ['of', 'is'],
#  "you'll": ['know', 'be'],
#  'know': ['when',
#   'what',
#   'not',
#   'how',
#   'what',
#   'love',
#   'so',
#   'ourselves!',
#   'yourself',
#   'why',
#   'what',
#   'how',
#   'how',
#   'when',
#   'what,',
#   'when'],
#  'when': ['you',
#   'I',
#   'everything',
#   'everything',
#   'pursued,',
#   'he',
#   'it',
#   'we',
#   'rap',
#   'I',
#   'I',
#   'I',
#   'some',
#   "I'm",
#   'people',
#   "I'm",
#   'I',
#   'my',
#   'I'],
#  'find': ['it.',
#   'the',
#   'the',
#   'my',
#   'something',
#   'the',
#   'that',
#   'so',
#   'them',
#   'the',
#   'Daniel'],
#  'it.': ['Change',
#   'Believe',
#   'A',
#   'Keep',
#   'Push',
#   'Thought',
#   'I',
#   'I',
#   'It',
#   "I've",
#   'We',
#   "It's",
#   'Since',
#   'But',
#   "They've",
#   'The',
#   'If'],
#  'Change': ['your'],
#  'thoughts': ['and', 'and'],
#  'world.': ['Health',
#   'We',
#   'Your',
#   'When',
#   'Once',
#   'I',
#   'Learning',
#   'It',
#   'As',
#   'I',
#   'It',
#   'If',
#   'I',
#   'It',
#   'I'],
#  'Health': ['is', 'is'],
#  'greatest': ['gift,',
#   'wealth,',
#   'power!',
#   'possession.',
#   'treasure.',
#   'friend.',
#   'joy.'],
#  'gift,': ['contentment'],
#  'contentment': ['the'],
#  'wealth,': ['faithfulness'],
#  'faithfulness': ['the'],
#  'best': ['relationship.', 'calorie', 'to', 'in', 'in', 'way', 'form'],
#  'relationship.': ['Today'],
#  'Today': ['I', 'is'],
#  'choose': ['life.', 'joy,', 'to', 'a'],
#  'life.': ['Every',
#   'There',
#   'Comes',
#   'Your',
#   'The',
#   'I',
#   'And',
#   'Teachers',
#   'Architecture'],
#  'Every': ['morning',
#   'moment',
#   'story',
#   'day',
#   "man's",
#   'charitable',
#   'heart',
#   'song',
#   'video'],
#  'morning': ['when', 'and'],
#  'wake': ['up'],
#  'up': ['I',
#   'then,',
#   'when',
#   'with',
#   'trying',
#   'longing',
#   'my',
#   'to',
#   'close,',
#   'with',
#   'a',
#   'stuff',
#   'your',
#   'to',
#   'to',
#   'against',
#   'over',
#   'to,',
#   'in',
#   'thinking',
#   'in',
#   'your',
#   'in'],
#  'joy,': ['happiness,'],
#  'happiness,': ['negativity,'],
#  'negativity,': ['pain...'],
#  'pain...': ['To'],
#  'To': ['feel',
#   'love',
#   'forgive',
#   'the',
#   'believe',
#   'not',
#   'not',
#   'be',
#   'cut',
#   'me,'],
#  'feel': ['the', 'life,', 'to', 'we', 'equal.', 'like', 'from', 'so', 'like'],
#  'freedom': ['that'],
#  'comes': ['from', 'from', 'from', 'to'],
#  'from': ['being',
#   'a',
#   'yesterday.',
#   'the',
#   'the',
#   'a',
#   'the',
#   'doing',
#   'giving?',
#   'within.',
#   'the',
#   'me.',
#   'talk',
#   'God.',
#   'start',
#   'your',
#   'the',
#   'our',
#   'a',
#   'a',
#   'behind',
#   'Arkansas,',
#   'the'],
#  'being': ['able',
#   'shared.',
#   'strong',
#   'has',
#   'inspirational',
#   'able',
#   'on',
#   'directed'],
#  'able': ['to', 'to', 'to'],
#  'continue': ['to', 'in', 'to', 'to'],
#  'make': ['mistakes',
#   'our',
#   'our',
#   'others',
#   'a',
#   'you',
#   'us',
#   'great',
#   'real',
#   'another',
#   'money,',
#   'my',
#   'people',
#   'people',
#   'people',
#   'up',
#   'myself',
#   'up',
#   'this',
#   'our',
#   'itself',
#   'a',
#   'outfits.',
#   'people'],
#  'mistakes': ['and'],
#  'choices': ['-'],
#  '-': ['today',
#   'and',
#   'and',
#   'as',
#   'I',
#   'at',
#   'that',
#   'and',
#   'all',
#   'not',
#   'an',
#   'either',
#   'activity',
#   'and',
#   "I'm",
#   'Gandhi,',
#   "they're",
#   'the',
#   'even',
#   'written',
#   'is',
#   'but',
#   'Diana,',
#   'and',
#   'only',
#   'my',
#   'a',
#   'truly',
#   'I',
#   'the',
#   'a',
#   'until',
#   'for',
#   'and',
#   'and'],
#  'today': ['I', 'because', 'so', 'is', 'we'],
#  'deny': ['my'],
#  'humanity': ['but'],
#  'embrace': ['it.'],
#  'Believe': ['you'],
#  "you're": ['halfway',
#   'not',
#   'free.',
#   'lucky,',
#   'up',
#   'trying',
#   'from.',
#   'just'],
#  'halfway': ['there.'],
#  'there.': ['My', 'Man'],
#  'My': ['mission',
#   'belief',
#   'goal',
#   'father,',
#   'mother,',
#   "mind's",
#   'mother',
#   'life',
#   'tastes',
#   'initial'],
#  'mission': ['in'],
#  'merely': ['to', 'determine', 'to'],
#  'survive,': ['but'],
#  'thrive;': ['and'],
#  'some': ['passion,',
#   'compassion,',
#   'humor,',
#   'style.',
#   'extraordinary',
#   'of',
#   'small',
#   'inspirational',
#   'sort',
#   'communities,'],
#  'passion,': ['some'],
#  'compassion,': ['some'],
#  'humor,': ['and'],
#  'style.': ['No'],
#  'No': ['act', 'matter'],
#  'act': ['of', 'upon...', 'is', 'of'],
#  'kindness,': ['no'],
#  'no': ['matter',
#   'longer',
#   'limits.',
#   'one',
#   'mountain',
#   'trouble',
#   'night,',
#   'matter',
#   'matter',
#   'sense',
#   'control',
#   'longer'],
#  'matter': ['how', 'what', 'what', 'but', 'where'],
#  'how': ['small,',
#   'great',
#   'you',
#   'to',
#   'good',
#   'big',
#   'any',
#   'to',
#   'to',
#   'to',
#   'much',
#   'much',
#   'I',
#   'we'],
#  'small,': ['is'],
#  'ever': ['wasted.',
#   'been.',
#   'bubble',
#   'dig.',
#   'dreamed',
#   'hear',
#   'done',
#   'my',
#   'seen...',
#   'seen.'],
#  'wasted.': ['Keep'],
#  'Keep': ['your', 'your', 'all'],
#  'face': ['always', 'to', 'the'],
#  'toward': ['the', 'heaven.'],
#  'sunshine': ['-'],
#  'shadows': ['will', 'fall'],
#  'will': ['fall',
#   'not',
#   'love',
#   'endure',
#   'spread',
#   'still',
#   'try.',
#   'sit',
#   'disappear',
#   'continue',
#   'open',
#   'make',
#   'turn.',
#   'spread',
#   'bring',
#   'come.',
#   'change',
#   'find',
#   'ever',
#   'change',
#   'take',
#   'ever',
#   'always',
#   'continue',
#   'stop',
#   'lead',
#   'be',
#   'inspire',
#   'say',
#   're-define',
#   'understand',
#   'show',
#   'be',
#   'be',
#   'transcend',
#   'see',
#   'always'],
#  'fall': ['behind', 'behind'],
#  'behind': ['you.', 'you', 'you.', 'it', "Houston's", 'it.', 'the'],
#  'you.': ['If', 'What', 'I', 'Give', 'What', 'Nurture', 'But', 'You', 'I'],
#  'opportunity': ["doesn't", 'may'],
#  "doesn't": ['knock,', 'have', 'say', 'last', 'reward'],
#  'knock,': ['build'],
#  'build': ['a', 'from', 'a', 'beneath', 'up', 'some'],
#  'door.': ['Perfection', "They've"],
#  'Perfection': ['is'],
#  'attainable,': ['but'],
#  'if': ['we',
#   'you',
#   'you',
#   'I',
#   'one',
#   'you',
#   'possible,',
#   'thou',
#   'this',
#   "there's",
#   'you',
#   'you',
#   "it's",
#   "you're",
#   "they've",
#   'it',
#   "that's",
#   'I',
#   'I',
#   'it',
#   'inside',
#   'I'],
#  'chase': ['perfection'],
#  'perfection': ['we'],
#  'catch': ['excellence.'],
#  'excellence.': ['What'],
#  'What': ['lies',
#   'we',
#   'you',
#   'you',
#   'makes',
#   'great',
#   'we',
#   'we',
#   'the',
#   'were',
#   'You',
#   'they'],
#  'lies': ['behind', 'in', 'inside', 'ahead', 'the'],
#  'front': ['of', 'of'],
#  'you,': ['pales', 'words', 'till', 'and', 'kindle'],
#  'pales': ['in'],
#  'comparison': ['to'],
#  'inside': ['of', 'of', 'the'],
#  'think,': ['we', 'aesthetically,'],
#  'become.': ['Let'],
#  'Let': ['us', 'us', 'us', 'your', 'him', 'us', 'each', 'every'],
#  'us': ['remember:',
#   'sacrifice',
#   'make',
#   'make',
#   'infinite.',
#   'at',
#   'what',
#   'dream',
#   'is',
#   'who',
#   'have',
#   'in',
#   'above',
#   'to',
#   'brave.',
#   'or',
#   'to',
#   'like',
#   'to',
#   'how'],
#  'remember:': ['One'],
#  'One': ['book,', 'today', 'of', 'of'],
#  'book,': ['one'],
#  'pen,': ['one'],
#  'child,': ['and'],
#  'teacher': ['can', 'at'],
#  'are,': ['but', 'but'],
#  'be.': ['Clouds', 'Find', 'I'],
#  'Clouds': ['come'],
#  'come': ['floating', 'our', 'to', 'to', 'out'],
#  'floating': ['into'],
#  'longer': ['to', 'with'],
#  'carry': ['rain', 'yourself.'],
#  'rain': ['or', 'drops'],
#  'or': ['usher',
#   'the',
#   'her',
#   'anything',
#   'any',
#   'to',
#   'far',
#   'bad',
#   'future...',
#   'losers.',
#   'a',
#   'forty',
#   'hides,',
#   "bear's,",
#   'only',
#   'enthusiasm.',
#   'hip-hop',
#   'people',
#   'thought,',
#   'word,',
#   "'punk,'",
#   'a',
#   'little',
#   'respected.',
#   'feel',
#   'putting',
#   'sketch',
#   'improv',
#   'the',
#   'inspirational',
#   'your',
#   'scenarios',
#   'songs',
#   'trying',
#   'someone',
#   'inspirational,',
#   'person.',
#   'inspirational',
#   'see'],
#  'usher': ['storm,'],
#  'storm,': ['but'],
#  'add': ['color', 'on'],
#  'color': ['to'],
#  'sunset': ['sky.'],
#  'sky.': ['Someone'],
#  'Someone': ['is'],
#  'sitting': ['in'],
#  'shade': ['today'],
#  'because': ['someone', 'it', 'he', 'it', 'they', 'a', "you're"],
#  'someone': ['planted',
#   'who',
#   'who',
#   'and',
# ...
#  'bliss': ['and'],
#  'universe': ['will', 'surrenders.', 'has'],
#  'open': ['doors', 'a'],
#  'doors': ['where', 'of'],
#  'there': ['were',
#   'for',
#   'were',
#   'is',
#   'is',
#   'waiting',
#   'are',
#   'and',
#   'can',
#   'to',
#   'and',
#   'is',
#   'will',
#   'so'],
#  'were': ['only',
#   'no',
#   'cleansed',
#   'awesome.',
#   'very',
#   'once',
#   'so',
#   'impossible.',
#   'always',
#   'young'],
#  'walls.': ['The'],
#  'power': ['of', 'of', 'that', 'to', 'and', 'of', 'in'],
#  'imagination': ['makes'],
#  'makes': ['us', 'the', 'heroes.', 'a', 'winners', 'us', 'one', 'it'],
#  'infinite.': ["Don't", 'How'],
#  'yourself.': ['Many', "It's", 'Lord,', 'A', 'To', 'As'],
#  'Many': ['people'],
#  'themselves': ['to', 'to', 'inspirational'],
#  'far': ['as', 'away.', 'as', 'into', 'more', 'as', 'as'],
#  'mind': ['lets', 'that', 'and'],
#  'lets': ['you.'],
#  'believe,': ['remember,', 'that', 'and'],
#  'remember,': ['you'],
#  'achieve.': ['Whoever'],
#  'Whoever': ['is'],
#  'others': ['happy', 'to', 'to', 'to', 'as', 'to'],
#  'too.': ['When', 'Nothing'],
#  'get': ['into',
#   'it.',
#   'into',
#   'my',
#   'what',
#   'out',
#   'me',
#   'something',
#   'a',
#   'your',
#   'in',
#   'a',
#   'up',
#   'up',
#   'older',
#   'excited',
#   'into',
#   'back'],
#  'tight': ['place'],
#  'goes': ['against'],
#  'against': ['you,', 'challenges'],
#  'till': ['it'],
#  'though': ['you'],
#  'could': ['not', 'we', 'not', 'only', 'be', 'ask'],
#  'hang': ['on'],
#  'longer,': ['never'],
#  'give': ['up', 'it', 'up', 'up', 'you', 'you', 'them'],
#  'then,': ['for'],
#  'tide': ['will'],
#  'turn.': ['Every'],
#  'moment': ['and', 'before', 'and', 'will', 'of', 'that', 'in'],
#  'event': ['of'],
#  "man's": ['life', 'greatest', 'reach', 'life', 'listening'],
#  'earth': ['plants', 'can'],
#  'plants': ['something'],
#  'soul.': ['The', 'Your', 'Go', 'I'],
#  'limits': ['of', 'of'],
#  'possible': ['can', 'is', 'by'],
#  'defined': ['by'],
#  'them': ['into', 'into', 'at', 'and', 'to', 'very', 'to', 'hope.'],
#  'resides': ['not'],
#  'possessions,': ['and'],
#  'gold,': ['happiness'],
#  'happiness': ['dwells'],
#  'dwells': ['in'],
#  'big': ['opportunity',
#   'movie',
#   'aim',
#   'personal',
#   'God',
#   'idea.',
#   'screen,',
#   'fan'],
#  'right': ['where', 'now', 'through', 'Scripture', 'brain/left-brain'],
#  'now.': ['Today'],
#  'day.': ['Yesterday', 'They', 'A'],
#  'Yesterday': ['is', 'we'],
#  'gone.': ['Somewhere,'],
#  'Somewhere,': ['something'],
#  'incredible': ['is', 'being'],
#  'known.': ['How'],
#  'How': ['wonderful', 'much', 'glorious'],
#  'wonderful': ['it', 'when'],
#  'nobody': ['need'],
#  'wait': ['a'],
#  'before': ['starting', 'I', 'emperors.', 'my', 'I', 'thee.'],
#  'starting': ['to'],
#  'improve': ['the'],
#  'Once': ['we', 'I'],
#  'ourselves,': ['we'],
#  'risk': ['curiosity,'],
#  'curiosity,': ['wonder,'],
#  'wonder,': ['spontaneous'],
#  'spontaneous': ['delight,'],
#  'delight,': ['or'],
#  'any': ['experience',
#   'of',
#   'material',
#   'time',
#   'other.',
#   'of',
#   'tough',
#   'kind'],
#  'experience': ['that', "life's", 'it'],
#  'reveals': ['the'],
#  'human': ['spirit.',
#   'life',
#   'has',
#   'being',
#   'spirit.',
#   'activities,',
#   'passions.',
#   'environment,',
#   'spaceflight'],
#  'spirit.': ['A', "It's"],
#  'champion': ['is'],
#  'gets': ['up', 'through'],
#  'he': ["can't.",
#   'hears',
#   'hears,',
#   'cannot',
#   'can',
#   'cannot',
#   'can',
#   'knows.',
#   'was',
#   'managed',
#   'is'],
#  "can't.": ['Everyone'],
#  'Everyone': ['has', 'here'],
#  'piece': ['of', 'of', 'of', 'of'],
#  'good': ['news.',
#   'news',
#   'where',
#   'put',
#   'or',
#   'poem,',
#   'inspirational',
#   'enough',
#   'one,',
#   'and',
#   'for',
#   'skill.',
#   'God,',
#   'combination',
#   'and'],
#  'news.': ['The'],
#  'news': ['is', 'of'],
#  'be!': ['How'],
#  'much': ['you', 'history.', 'hip-hop.', 'effort', 'moral'],
#  'love!': ['What'],
#  'accomplish!': ['And'],
#  'potential': ['is!', 'for', 'of'],
#  'is!': ['Love'],
#  'energy': ['of'],
#  'boundaries.': ['Even'],
#  'Even': ['if'],
#  'knew': ['that', 'only', 'you'],
#  'would': ['go',
#   'still',
#   'literally',
#   'end',
#   'not',
#   'appear',
#   'you',
#   'never',
#   'be',
#   'have',
#   'outpoint',
#   'have',
#   'say',
#   'think',
#   'feed',
#   'always',
#   'be',
#   'be',
#   'probably'],
#  'pieces,': ['I'],
#  'plant': ['my', 'a', 'a'],
#  'apple': ['tree.'],
#  'tree.': ['Thinking:'],
#  'Thinking:': ['the'],
#  'talking': ['of'],
#  'Each': ['day'],
#  'provides': ['its'],
#  'gifts.': ['Accept'],
#  'Accept': ['the'],
#  'fate': ['binds', 'brings'],
#  'binds': ['you,'],
#  'whom': ['fate'],
#  'brings': ['you', 'new'],
#  'together,': ['but'],
#  'heart.': ['If', 'One', 'We', 'Have', 'We'],
#  'did': ['all',
#   'before',
#   'it',
#   'it',
#   "'Antony",
#   'a',
#   'things',
#   'an',
#   'see.',
#   'you'],
#  'capable': ['of,'],
#  'of,': ['we'],
#  'literally': ['astound', 'make'],
#  'astound': ['ourselves.'],
#  'With': ['self-discipline', 'my', 'Laila'],
#  'self-discipline': ['most'],
#  'possible.': ['What'],
#  'desert': ['beautiful'],
#  'beautiful': ['is', 'and', 'thing', 'pictures', 'things;'],
#  'somewhere': ['it'],
#  'hides': ['a'],
#  'well.': ['The', 'Not', "Roosevelt's"],
#  'journey': ['is', 'for', 'into'],
#  'within.': ['Throw', 'Within', 'You'],
#  'Throw': ['your'],
#  'space': ['like', 'as', 'you', 'program', 'in', 'our', 'sounds'],
#  'kite,': ['and'],
#  'back,': ['a'],
#  'new': ['life,',
#   'friend,',
#   'love,',
#   'country.',
#   'action',
#   'strength.',
#   'book',
#   'wave'],
#  'friend,': ['a'],
#  'love,': ['a'],
#  'country.': ['Happiness'],
#  'natural': ['flower', 'human'],
#  'flower': ['of'],
#  'duty.': ['If'],
#  'cold': ['to'],
#  'kindle': ['fires'],
#  'fires': ['to'],
#  'warm': ['it.', 'thought'],
#  'feet': ['on'],
#  'ground,': ['but'],
#  'heart': ['soar', 'of', 'leaped', 'is', 'near', 'that', 'of'],
#  'soar': ['as'],
#  'will.': ['Refuse', 'My', 'Countless'],
#  'Refuse': ['to'],
#  'average': ['or'],
#  'surrender': ['to'],
#  'chill': ['of'],
#  'spiritual': ['environment.', 'exercises.', 'grace', 'warfare', 'home'],
#  'environment.': ['Tomorrow'],
#  'Tomorrow': ['is'],
#  'Comes': ['into'],
#  'midnight': ['very'],
#  'clean.': ["It's"],
#  "It's": ['perfect',
#   'part',
#   'part',
#   'an',
#   'aspirational,',
#   'a',
#   'music.',
#   'supposed',
#   'the',
#   'the',
#   'a',
#   'very',
#   'what',
#   'so',
#   'art',
#   'inspirational,',
#   'inspirational',
#   'horrible!',
#   'as',
#   'an',
#   'empowering,',
#   'very'],
#  'perfect': ['when'],
#  'arrives': ['and'],
#  'puts': ['itself'],
#  'hands.': ['It', 'Do'],
#  'hopes': ["we've", 'make', 'for', 'and'],
#  "we've": ['learned'],
#  'learned': ['something', 'the'],
#  'yesterday.': ['We'],
#  'lives.': ['We', 'Better', 'I', 'Plant'],
#  'have,': ['and'],
#  'exactly': ['what', '13', 'how'],
#  'wish.': ['I'],
#  'looked': ['at', 'into'],
#  'skies,': ['one'],
#  'wings.': ['The'],
#  'are.': ['The', 'Light'],
#  'full': ['of', 'of', 'of', 'of'],
#  'magical': ['things'],
#  'patiently': ['waiting'],
#  'wits': ['to'],
#  'sharper.': ['I'],
#  'thank': ['you'],
#  'this': ['most',
#   'Earth',
#   'day.',
#   'is',
#   'world',
#   'collective',
#   'world',
#   'thing',
#   'inspirational',
#   'was',
#   'a',
#   'is',
#   'was',
#   'world.'],
#  'amazing': ['day,', 'courage', 'friends'],
#  'day,': ['for', 'nor', 'the'],
#  'leaping': ['greenly'],
#  'greenly': ['spirits'],
#  'spirits': ['of'],
#  'trees,': ['and'],
#  'blue': ['dream'],
#  'dream': ['of', 'of', 'can', 'of', 'about', 'big.'],
#  'sky': ['and'],
#  'natural,': ['which'],
#  'infinite,': ['which'],
#  'yes.': ['Everyone'],
#  'here': ['has', 'and', 'to', 'is', 'for', 'to', 'to', 'to'],
#  'sense': ['that', 'of', 'of'],
#  'influencing': ['the'],
#  'future.': ['Every', 'You', 'She'],
#  'story': ['I', 'which', 'or', 'needed'],
#  'create,': ['creates', 'to', 'and'],
#  'creates': ['me.', 'the'],
#  'me.': ['I',
#   'I',
#   'On',
#   'The',
#   'Let',
#   'I',
#   'I',
#   'I',
#   'Who',
#   'I',
#   'Whatever',
#   'Every',
#   'We',
#   'I',
#   'When',
#   'The'],
#  'write': ['to', 'equality', '10'],
#  'create': ['myself.', 'an', 'a', 'something'],
#  'myself.': ['To', 'I'],
#  'still,': ['the', 'to'],
#  'whole': ['universe',
#   'persona',
#   'world',
#   'world',
#   'lives,',
#   'body.',
#   'order',
#   'CD'],
#  'surrenders.': ['Live'],
#  'Live': ['your', 'to'],
#  'beliefs': ['and'],
#  'turn': ['the'],
#  'around.': ['You', 'It'],
#  'look': ['out',
#   'in',
#   'up',
#   'at',
#   'very',
#   'and',
#   'for',
#   'at',
#   'forward',
#   'up',
#   'forward',
#   'up',
#   'at'],
#  'God,': ['something', 'now'],
#  'sky,': ['you', 'pushed'],
#  'Nurture': ['your'],
#  'minds': ['with'],
#  'thoughts.': ['To'],
#  'heroic': ['makes'],
#  'heroes.': ['If'],
#  'man': ['does', 'as', 'should', 'has', 'exercise', 'who'],
#  'does': ['not', 'not'],
#  'pace': ['with'],
#  'companions,': ['perhaps'],
#  'perhaps': ['it', 'would'],
#  'hears': ['a'],
#  'different': ['drummer.', 'future,', 'past.', 'cultures', 'ways', 'artists'],
#  'drummer.': ['Let'],
#  'step': ['to'],
#  'music': ['which', 'in', 'out', 'is', "I've", 'and', 'stays', "isn't."],
#  'hears,': ['however'],
#  'however': ['measured'],
#  'measured': ['or'],
#  'away.': ['I'],
#  'dwell': ['in'],
#  'possibility.': ['Tears'],
#  'Tears': ['of', 'are'],
#  'joy': ['are', 'we'],
#  'summer': ['rain'],
#  'drops': ['pierced'],
#  'pierced': ['by'],
#  'sunbeams.': ['If'],
#  'night,': ['we'],
#  'appreciate': ['the'],
#  'nor': ['could', 'in'],
#  'stars': ['and'],
#  'vastness': ['of'],
#  'heavens.': ['We'],
#  'partake': ['of'],
#  'bitter': ['with'],
#  'sweet.': ['There'],
#  'divine': ['purpose', 'love?'],
#  'purpose': ['in'],
#  'adversities': ['we'],
#  'encounter': ['every'],
#  'They': ['prepare,', 'are', 'talk'],
#  'prepare,': ['they'],
#  'purge,': ['they'],
#  'purify,': ['and'],
#  'thus': ['they'],
#  'bless.': ['The'],
#  'through.': ['Keep'],
#  'special': ['thoughts', 'moment'],
#  'memories': ['for'],
#  'lifetimes': ['to'],
#  'come.': ['Share', 'Let'],
#  'Share': ['these'],
#  'these': ['keepsakes', 'is'],
#  'keepsakes': ['with'],
#  'inspire': ['hope', 'respect.', 'people,', 'the', 'my', 'people,', 'others'],
#  'hope': ['and', 'point', 'that'],
#  'past,': ['which'],
#  'bridge': ['to'],
#  'changing': ['your', 'things'],
#  'worth': ['two', 'more', 'more', 'doing.'],
#  'tomorrows.': ['Find'],
#  'Find': ['out', 'that'],
#  'person.': ["That's", 'My', 'It', 'This'],
#  "That's": ['what', 'what', 'what'],
#  'Earth': ['to'],
#  'truth,': ['live', 'follow'],
#  'truth': ['and', 'at', 'and', 'of', 'is'],
#  'soul,': ['and', 'the'],
#  'ultimate': ['truth', 'achievements.'],
#  'creation.': ['Only'],
#  'Only': ['those'],
#  'sincere': ['and', 'thanks'],
#  'selfless': ['contribution'],
#  'contribution': ['experience'],
#  "life's": ['deepest', 'jewels'],
#  'deepest': ['joy:'],
#  'joy:': ['true'],
#  'true': ['fulfillment.'],
#  'fulfillment.': ['Do'],
#  'Do': ['your', 'they'],
#  'little': ['bit', 'bits', 'word', 'song,', 'higher.', 'by'],
#  'bit': ['of', 'of', 'sterile.'],
#  'are;': ["it's"],
#  "it's": ['those',
#   'not',
#   'a',
#   'a',
#   'how',
#   'inspirational.',
#   'not',
#   'all',
#   'kind',
#   'a',
#   'inspirational.',
#   'inspirational.',
#   'something',
#   'really',
#   'in',
#   'something',
#   'a',
#   'also',
#   'disgusting',
#   'wonderful',
#   'inspirational',
#   'a',
#   'inspirational',
#   'what',
#   'an',
#   'a'],
#  'bits': ['of'],
#  'together': ['that'],
#  'overwhelm': ['the'],
#  'believed,': ['and'],
#  'whatever': ['good', 'it', 'is', 'is', 'is', 'is', 'is', 'you'],
#  'bad': ['fortune', 'weather'],
#  'fortune': ['may'],
#  'meaning': ['and', 'I'],
#  'transform': ['it'],
#  'value.': ['From', 'If'],
#  'get,': ['we'],
#  'living;': ['what'],
#  'give,': ['however,'],
#  'however,': ['makes'],
#  'ordinary': ['acts', 'that'],
#  'acts': ['of', 'and'],
#  'point': ['to', 'of'],
#  'extraordinary': ['promise', 'to', 'spiritual', 'amount'],
#  'promise': ['that', 'of'],
#  'inestimable': ['value.'],
#  'perception': ['were'],
#  'cleansed': ['everything'],
#  'appear': ['to'],
#  'is,': ['infinite.', 'but', 'of'],
#  'glorious': ['a', 'piece', 'day'],
#  'greeting': ['the'],
#  'mountains!': ['The'],
#  'glow': ['of'],
#  'thought': ['is', 'are', 'she', 'that', "'Moulin"],
#  'more': ['than',
#   'people',
#   'than',
#   'than',
#   'courage',
#   'women',
#   'inclusive.',
#   'inspirational.',
#   'inspirational.',
#   'interesting.',
#   'than',
#   'an'],
#  'money.': ['Vitality'],
#  'Vitality': ['shows'],
#  'ability': ['to', 'to'],
#  'persist': ['but'],
#  'start': ['over.', 'to', 'the'],
#  'over.': ['If'],
#  'expectations': ['of'],
#  'especially': ['negative', 'on'],
#  'negative': ['ones,'],
#  'ones,': ['then'],
#  'outcome.': ['The'],
#  'stronger': ['in'],
#  'gentleness.': ['Look'],
#  'Look': ['at', 'within.'],
#  'football': ['field.', 'career.'],
#  'field.': ['It'],
#  'looks': ['like', 'a', 'to', "healthy.'"],
#  'movie': ['screen.', 'for'],
#  'screen.': ['This'],
#  'theatre.': ['Football'],
#  'Football': ['combines'],
#  'combines': ['the'],
#  'strategy': ['of'],
#  'chess.': ["It's"],
#  'ballet.': ["It's"],
#  'battleground,': ['part'],
#  'playground.': ['We'],
#  'clarify,': ['amplify'],
#  'amplify': ['and'],
#  'glorify': ['the'],
#  'game': ['with'],
#  'footage,': ['the'],
#  'narration': ['and'],
#  'music,': ['and', 'and'],
#  'an': ['inspirational',
#   'idea,',
#   'inner',
#   "ox's",
#   'encouragement',
#   'inspirational',
#   'inspirational',
#   'inspirational',
#   'inspirational',
#   'educator.',
#   'inspirational',
#   'inspirational',
#   'inspirational',
#   'inspirational',
#   'extraordinary',
#   'end',
#   'inspirational',
#   'ice-cream',
#   'enormous',
#   'inspirational',
#   'inspirational',
#   'engine',
#   'overwhelmingly',
#   'inspirational',
#   'inspirational',
#   'honor',
#   'inspirational',
#   'A',
#   'inspirational',
#   'inspirational',
#   'orchestra',
#   'Indian',
#   'inspirational',
#   'artist',
#   'inspirational',
#   'inspirational',
#   'upper.',
#   'inspirational,',
#   'emerging',
#   'inspirational',
#   'inspirational',
#   'artist.',
#   'inspirational',
#   'art',
#   'inspirational'],
#  'footage.': ['The'],
#  'fact': ['that'],
#  'becomes': ['a', "another's,", 'a'],
#  'flower,': ['share'],
#  'share': ['a', 'is'],
#  'knowledge': ['and', 'the', 'increases,', 'which'],
#  "another's,": ['smile'],
#  'smile': ['at', 'in'],
#  'receive': ['a'],
#  'return,': ['are'],
#  'continual': ['spiritual'],
#  'exercises.': ['The'],
#  'authentic': ['thing', 'self'],
#  'about': ['us',
#   'that!',
#   'New',
#   'their',
#   'status',
#   'it...',
#   'disability',
#   'how',
#   'what',
#   'young',
#   'the',
#   'it',
#   'a',
#   'her',
#   'it.'],
#  'capacity': ['to'],
#  'overcome,': ['to'],
#  'endure,': ['to'],
#  'transform,': ['to'],
#  'greater': ['than', 'than'],
#  'suffering.': ['Prayer'],
#  'Prayer': ['is'],
#  'power!': ['A'],
#  '#2': ['pencil'],
#  'pencil': ['and'],
#  'take': ['you', 'you', 'action', 'action', 'my', 'a', 'advantage'],
#  'anywhere.': ['Health'],
#  'possession.': ['Contentment'],
#  'Contentment': ['is'],
#  'treasure.': ['Confidence'],
#  'Confidence': ['is'],
#  'friend.': ['Non-being'],
#  'Non-being': ['is'],
#  'joy.': ['Reach'],
#  'Reach': ['for', 'for'],
#  'Push': ['yourself'],
#  'can.': ['Reach'],
#  'books': ['that'],
#  'most.': ['The'],
#  'hardest': ['way'],
#  'learning': ['is'],
#  'easy': ['reading;'],
#  'reading;': ['but'],
#  'book': ['that', "that's"],
#  'thinker': ['is'],
#  'ship': ['of'],
#  'thought,': ['deep', 'or', 'an', "'Okay,"],
#  'deep': ['freighted'],
#  'freighted': ['with'],
#  'beauty.': ['The'],
#  'undertaking': ['of'],
#  'action': ['brings', 'to', 'and'],
#  'strength.': ['Try'],
#  'turtle': ['-'],
#  'ease': ['in'],
#  'shell.': ['Cherish'],
#  'Cherish': ['your'],
#  'visions': ['and', 'of'],
#  'blueprints': ['of'],
#  'achievements.': ['Ah,'],
#  'Ah,': ['but'],
#  'should': ['exceed', 'hear', 'never', 'have', 'not', 'do'],
#  'exceed': ['his'],
#  'Or': ["what's"],
#  'heaven': ['for?', 'of', 'to'],
#  'for?': ['Brand'],
#  'Brand': ['is'],
#  'product,': ["that's"],
#  "that's": ['for', 'highly', 'what', 'a', 'why', 'the', 'exactly', 'all.'],
#  'sure;': ["it's"],
#  'item.': ["It's"],
#  'idea,': ["it's"],
#  'theory,': ["it's"],
#  'meaning,': ["it's"],
#  'aspirational,': ["it's"],
#  'inspirational.': ['Once',
#   'Public',
#   'You',
#   'It',
#   'The',
#   'Benazir',
#   'You',
#   'Reading',
#   'I',
#   'If',
#   'Why',
#   'I',
#   'Just',
#   'My',
#   'But',
#   'Then',
#   'I',
#   'The',
#   'And',
#   'I',
#   'It',
#   "It's",
#   'And',
#   'Since',
#   'I',
#   'Thelonious',
#   'I',
#   'I'],
#  'stillness...': ['my'],
#  'without': ['past', 'taking', 'at', 'my'],
#  'past': ['or', '-'],
#  'future...': ['but'],
#  'fingers': ['of'],
#  'fell': ['into', 'for'],
#  'hand': ['that'],
#  'clutched': ['at'],
#  'emptiness,': ['and'],
#  'leaped': ['to'],
#  'rapture': ['of'],
#  'living.': ['What'],
#  'attempt': ['if'],
#  ...}

# %% [markdown]
# ## Create a Text Generator
# We're going to create a function that generates sentences. It will take two things as inputs:
#
# 1.The dictionary you just created
#
# 2.The number of words you want generated
#
# Here are some examples of generated sentences:
#
# 1. 'Shadows fall behind you. What You must not a mere reed shaken in ourselves. With my friends are a mighty trunk may grow. Nothing makes it shows me to live each day provides its own.'
#
# 2. 'Scars from a special thoughts and will. Countless as putting an inspirational to always gives you carry rain or inspirational performance, I go out with.'
#
# 3. "Defy it. I've never decreases by reinvention. To cut yourself and everything which is a better tomorrow. I get it. Change your little higher. Act."
#
# 4. "Blessedness greater than oneself. Don't judge."

# %%
import random

def generate_sentence(chain, count=10):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''

    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

    # End it with a period
    sentence += '.'
    return(sentence)

# %%
generate_sentence(data_dict)
# Out:
# 'Realize whatever is so inspirational, then he can relate to..'
